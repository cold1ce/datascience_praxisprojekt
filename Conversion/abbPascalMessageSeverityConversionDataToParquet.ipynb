# %%
import pickle
import pandas as pd
import numpy as np

# %%
X = pd.read_pickle("D:/Eclipse Python/DataScience/res/event_ano.pkl")

# %%
X
# Out:
#             event_timestamp message_number message_category message_severity  \
# 0       2016-07-04 16:19:35          10010      Operational      Information
# 1       2016-07-04 16:19:35          10017      Operational      Information
# 2       2016-07-04 16:19:35          10016      Operational      Information
# 3       2016-07-04 16:19:34          10015      Operational      Information
# 4       2016-07-04 16:19:34          10012      Operational      Information
# 5       2016-07-04 16:19:34          10011      Operational      Information
# 6       2016-07-04 16:19:33          10017      Operational      Information
# 7       2016-07-04 16:19:33          10016      Operational      Information
# 8       2016-07-04 16:19:32          40168          Program          Warning
# 9       2016-07-04 16:19:32         134010            Paint            Error
# 10      2016-07-04 16:19:26          10129      Operational      Information
# ...

# %%
X.dtypes
# Out:
# event_timestamp     datetime64[ns]
# message_number              object
# message_category            object
# message_severity            object
# an_title                    object
# an_description              object
# an_line                     object
# an_cell                     object
# an_robot                    object
# dtype: object

# %% [markdown]
# #  Korrektur von message_severity

# %%
unique_message_severity = X['message_severity'].unique()
print(unique_message_severity)
# Out:
# ['Information' 'Warning' 'Error' 'Diagnose der Profinet-E/A-Einheit'
#  'Alarm der Profinet-E/A-Einheit' 'Max. Wartezeit abgelaufen'
#  'Automatik-Sicherheitshalt offen' 'Sicherheitsstopp-Zustand'
#  'SC 1 - OVR aktiv ' 'Überwachungsfehler Sicherheitskreis 2'
#  'Befehl nicht zulässig' 'OVR-Geschwindigkeit von SC 1 überschritten '
#  'Wiederanfahren fertig' 'Wiederanfahren gestartet' 'MOTOREN-EIN-Zustand'
#  'Backup-Schritt fertig' 'Cyclic Brake Check gestartet'
#  'Programm neu gestartet' 'MOTOREN-AUS-Zustand' 'Programm gestoppt'
#  'Zyklische Bremsenüberprüfung durchgeführt' 'Automatikbetrieb bestätigt'
#  'Automatikbetrieb angefordert' 'Motoren-EIN unzulässig'
#  'Einrichtbetrieb gewählt' ' Schweißsteuerung Fehler!! '
#  'Interrupt aus Warteschlange entfernt' ' Schweißzangen Fehler!! '
#  ' Warte auf Fraeser Umdrehungszaehler '
#  'Zweikanal-Fehler Sicherheitskreis' 'Programm gestartet.'
#  'Programmzeiger wurde zurückgesetzt' 'Start unzulässig'
# ...

# %%
unique_message_number = X['message_number'].unique()
print(unique_message_number)
# Out:
# ['10010' '10017' '10016' '10015' '10012' '10011' '40168' '134010' '10129'
#  '10150' '10002' '10125' '50024' '10155' '71201' '10045' '10122' '10151'
#  '10053' '10052' '10156' '20205' '10232' '50036' '50050' '10020' '50163'
#  '100000' '20074' '10019' '10018' '80002' '10021' '50026' '10097' '50143'
#  '20010' '10013' '10126' '10084' '10048' '40228' '10253' '10252' '10251'
#  '10250' '50316' '10046' '20206' '71439' '71518' '50376' '20314' '10270'
#  '10271' '71444' '40538' '71414' '20481' '20140' '20212' '10231' '10230'
#  '10123' '40210' '20211' '10025' '10026' '10024' '50204' '20224' '20225'
#  '10068' '40223' '41795' '20293' '50438' '20260' '20142' '71276' '71058'
#  '20216' '10128' '20390' '50361' '41581' '41595' '10131' '71521' '71520'
#  '20072' '20468' '40160' '20135' '71441' '20200' '10121' '50263' '41555'
#  '10130' '10260' '40502' '20054' '50028' '20490' '37001' '20485' '10214'
#  '20067' '20466' '71434' '71431' '71433' '20051' '50037' '20493' '40191'
# ...

# %%
X[X.message_number == '10010']
# Out:
#             event_timestamp message_number message_category message_severity  \
# 0       2016-07-04 16:19:35          10010      Operational      Information
# 19      2016-07-04 16:19:22          10010      Operational      Information
# 82      2016-07-04 15:26:27          10010      Operational      Information
# 103     2016-07-04 15:26:15          10010      Operational      Information
# 143     2016-07-04 13:29:32          10010      Operational      Information
# 156     2016-03-02 16:24:05          10010      Operational      Information
# 163     2016-07-04 13:29:11          10010      Operational      Information
# 284     2016-07-04 11:07:28          10010      Operational      Information
# 301     2016-07-04 10:58:57          10010      Operational      Information
# 322     2016-07-04 10:58:24          10010      Operational      Information
# 344     2016-07-04 07:59:54          10010      Operational      Information
# ...

# %% [markdown]
# # message_number=10010

# %%
# Rausfinde welche Kategorien für message_number=10010 vorkommen

# X[X.message_number == '10010'][X.message_severity != 'Information']
X.loc[X['message_number'] == '10010', "message_severity"].unique()
# Out:
# array(['Information', 'MOTOREN-AUS-Zustand'], dtype=object)

# %%
# Überprüfe ob es außer 10010 andere message_numbers gibt, welche auch  'MOTOREN-AUS-Zustand' als messagw_severity Kategorie haben

X.loc[X['message_severity'] == 'MOTOREN-AUS-Zustand', "message_number"].unique()
# Out:
# array(['10010'], dtype=object)

# %%
X[X.message_number == '10010'][X.message_severity == 'MOTOREN-AUS-Zustand']
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 324372  2015-08-17 23:37:04          10010      Operational
# 324381  2015-08-17 23:31:25          10010      Operational
# 324389  2015-08-17 22:36:11          10010      Operational
# 324398  2015-08-17 20:51:41          10010      Operational
# 324409  2015-08-17 17:15:49          10010      Operational
# 324417  2015-08-17 16:05:02          10010      Operational
# 324425  2015-08-17 15:58:18          10010      Operational
# 324433  2015-08-17 15:55:40          10010      Operational
# 324438  2015-08-17 14:21:24          10010      Operational
# 324446  2015-08-17 13:57:12          10010      Operational
# 324458  2015-08-17 23:37:15          10010      Operational
# 324467  2015-08-17 23:32:28          10010      Operational
# ...

# %%
# Erstelle eine Notkopie für die Kategorebereinigung

df1=X.copy()

# %%
# message_number=10010
# Ersätze falsche Kategorie 'MOTOREN-AUS-Zustand' mit 'Information'. 

df1['message_severity'] = df1.message_severity.replace({'MOTOREN-AUS-Zustand': 'Information'})

# Überprüfe message number=10010
df1.loc[df1['message_number'] == '10010', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=10017

# %%
# Überprüfe message_severity von message number=10017

X.loc[X['message_number'] == '10017', "message_severity"].unique()
# Out:
# array(['Information', 'Automatikbetrieb bestätigt'], dtype=object)

# %%
# Überprüfe ob es außer 10017 andere message_numbers gibt, welche auch  'Automatikbetrieb bestätigt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Automatikbetrieb bestätigt', "message_number"].unique()
# Out:
# array(['10017'], dtype=object)

# %%
X[X.message_number == '10017'][X.message_severity == 'Automatikbetrieb bestätigt'] # -> 225 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 324466  2015-08-17 23:32:30          10017      Operational
# 331812  2015-08-20 14:24:54          10017      Operational
# 331851  2015-08-20 14:04:21          10017      Operational
# 341271  2015-08-24 21:47:10          10017      Operational
# 341413  2015-08-24 17:50:18          10017      Operational
# 341434  2015-08-24 17:40:25          10017      Operational
# 341453  2015-08-24 17:31:24          10017      Operational
# 341719  2015-08-24 06:39:00          10017      Operational
# 341742  2015-08-24 06:36:56          10017      Operational
# 646828  2015-08-17 18:50:15          10017      Operational
# 654228  2015-08-18 09:56:17          10017      Operational
# 654766  2015-08-18 16:16:53          10017      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Automatikbetrieb bestätigt': 'Information'})

# Überprüfe message_severity von message number=10017
df1.loc[df1['message_number'] == '10017', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=10016

# %%
# Überprüfe message_severity von message number=10016

X.loc[X['message_number'] == '10016', "message_severity"].unique()
# Out:
# array(['Information', 'Automatikbetrieb angefordert'], dtype=object)

# %%
# Überprüfe ob es außer 10016 andere message_numbers gibt, welche auch  'Automatikbetrieb angefordert' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Automatikbetrieb angefordert', "message_number"].unique()
# Out:
# array(['10016'], dtype=object)

# %%
X[X.message_number == '10016'][X.message_severity == 'Automatikbetrieb angefordert'] # -> 201 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 324468  2015-08-17 23:32:28          10016      Operational
# 331814  2015-08-20 14:24:53          10016      Operational
# 331854  2015-08-20 14:04:18          10016      Operational
# 341273  2015-08-24 21:47:04          10016      Operational
# 341415  2015-08-24 17:50:16          10016      Operational
# 341436  2015-08-24 17:40:22          10016      Operational
# 341456  2015-08-24 17:30:48          10016      Operational
# 341721  2015-08-24 06:38:58          10016      Operational
# 341745  2015-08-24 06:36:53          10016      Operational
# 646830  2015-08-17 18:50:13          10016      Operational
# 654232  2015-08-18 09:56:14          10016      Operational
# 654769  2015-08-18 16:16:51          10016      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Automatikbetrieb angefordert': 'Information'})

# Überprüfe message_severity von message_number=10016
df1.loc[df1['message_number'] == '10016', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=10015

# %%
# Überprüfe message_severity von message number=10015

X.loc[X['message_number'] == '10015', "message_severity"].unique()
# Out:
# array(['Information', 'Einrichtbetrieb gewählt'], dtype=object)

# %%
# Überprüfe ob es außer 10015 andere message_numbers gibt, welche auch  'Einrichtbetrieb gewählt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Einrichtbetrieb gewählt', "message_number"].unique()
# Out:
# array(['10015'], dtype=object)

# %%
X[X.message_number == '10015'][X.message_severity == 'Einrichtbetrieb gewählt'] # -> 223 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 324476  2015-08-17 23:30:46          10015      Operational
# 331833  2015-08-20 14:24:34          10015      Operational
# 331865  2015-08-20 14:04:00          10015      Operational
# 341278  2015-08-24 21:45:03          10015      Operational
# 341420  2015-08-24 17:47:20          10015      Operational
# 341440  2015-08-24 17:39:31          10015      Operational
# 341476  2015-08-24 17:30:12          10015      Operational
# 341739  2015-08-24 06:37:20          10015      Operational
# 341834  2015-08-24 06:27:10          10015      Operational
# 646890  2015-08-17 18:43:10          10015      Operational
# 654248  2015-08-18 09:54:43          10015      Operational
# 655130  2015-08-18 15:46:07          10015      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Einrichtbetrieb gewählt': 'Information'})

# Überprüfe message_severity von message_number=10015
df1.loc[df1['message_number'] == '10015', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=10012

# %%
# Überprüfe message_severity von message number=10012

X.loc[X['message_number'] == '10012', "message_severity"].unique()
# Out:
# array(['Information', 'Sicherheitsstopp-Zustand'], dtype=object)

# %%
# Überprüfe ob es außer 10012 andere message_numbers gibt, welche auch  'Sicherheitsstopp-Zustand' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Sicherheitsstopp-Zustand', "message_number"].unique()
# Out:
# array(['10012'], dtype=object)

# %%
X[X.message_number == '10012'][X.message_severity == 'Sicherheitsstopp-Zustand'] # -> 9859 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 291801  2015-06-04 20:26:06          10012      Operational
# 291807  2015-06-04 20:26:10          10012      Operational
# 291811  2015-06-04 20:25:44          10012      Operational
# 291813  2015-06-04 20:27:09          10012      Operational
# 291815  2015-06-04 20:26:34          10012      Operational
# 291817  2015-06-04 20:27:00          10012      Operational
# 293573  2015-05-05 19:26:00          10012      Operational
# 293575  2015-05-05 13:07:00          10012      Operational
# 293577  2015-05-05 07:09:00          10012      Operational
# 293580  2015-05-04 22:10:00          10012      Operational
# 293582  2015-05-04 21:49:00          10012      Operational
# 293584  2015-05-04 19:40:00          10012      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Sicherheitsstopp-Zustand': 'Information'})

# Überprüfe message_severity von message_number=10012
df1.loc[df1['message_number'] == '10012', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=10011

# %%
# Überprüfe message_severity von message number=10011

X.loc[X['message_number'] == '10011', "message_severity"].unique()
# Out:
# array(['Information', 'MOTOREN-EIN-Zustand'], dtype=object)

# %%
# Überprüfe ob es außer 10011 andere message_numbers gibt, welche auch  'MOTOREN-EIN-Zustand' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'MOTOREN-EIN-Zustand', "message_number"].unique()
# Out:
# array(['10011'], dtype=object)

# %%
X[X.message_number == '10011'][X.message_severity == 'MOTOREN-EIN-Zustand'] # -> 8592  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 313237  2015-08-17 20:50:48          10011      Operational
# 314531  2015-08-17 15:56:52          10011      Operational
# 315378  2015-08-18 12:45:24          10011      Operational
# 316210  2015-08-19 08:00:30          10011      Operational
# 316457  2015-08-19 06:46:49          10011      Operational
# 317778  2015-08-17 17:16:02          10011      Operational
# 318866  2015-08-17 16:07:38          10011      Operational
# 319143  2015-08-20 14:03:44          10011      Operational
# 319612  2015-08-20 14:05:53          10011      Operational
# 320092  2015-08-17 13:59:24          10011      Operational
# 322398  2015-08-20 07:54:12          10011      Operational
# 322641  2015-08-24 18:05:48          10011      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'MOTOREN-EIN-Zustand': 'Information'})

# Überprüfe message_severity von message_number=10011
df1.loc[df1['message_number'] == '10011', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=40168

# %%
# Überprüfe message_severity von message number=40168

X.loc[X['message_number'] == '40168', "message_severity"].unique() # -> das passt, muss nicht angepasst werden
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=134010

# %%
# Überprüfe message_severity von message number=134010

X.loc[X['message_number'] == '134010', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10129

# %%
# Überprüfe message_severity von message number=10129

X.loc[X['message_number'] == '10129', "message_severity"].unique()
# Out:
# array(['Information', 'Programm gestoppt'], dtype=object)

# %%
# Überprüfe, ob es außer 10129 andere message_numbers gibt, welche auch  'Programm gestoppt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Programm gestoppt', "message_number"].unique()
# Out:
# array(['10125', '10123', '10122', '10130', '10126', '10129', '10133'],
#       dtype=object)

# %% [markdown]
# # Überprüfe die Kategorien von allen messages

# %%
# Überprüfe, ob message 10125 auch zu Kategorei Information gehört

X.loc[X['message_number'] == '10125', "message_severity"].unique()
# Out:
# array(['Information', 'Programm gestoppt'], dtype=object)

# %%
X[X.message_number == '10125'][X.message_severity == 'Programm gestoppt'] # ->  11228 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 324376  2015-08-17 23:36:30          10125      Operational
# 324384  2015-08-17 23:30:07          10125      Operational
# 324393  2015-08-17 22:35:58          10125      Operational
# 324401  2015-08-17 20:11:32          10125      Operational
# 324412  2015-08-17 17:15:00          10125      Operational
# 324420  2015-08-17 15:58:28          10125      Operational
# 324428  2015-08-17 15:56:31          10125      Operational
# 324436  2015-08-17 15:54:15          10125      Operational
# 324441  2015-08-17 14:21:00          10125      Operational
# 324449  2015-08-17 13:56:33          10125      Operational
# 324461  2015-08-17 23:36:42          10125      Operational
# 324479  2015-08-17 23:30:19          10125      Operational
# ...

# %%
# Überprüfe, ob message 10123 auch zu Kategorei Information gehört

X.loc[X['message_number'] == '10123', "message_severity"].unique()
# Out:
# array(['Information', 'Programm gestoppt'], dtype=object)

# %%
X[X.message_number == '10123'][X.message_severity == 'Programm gestoppt'] # -> 521  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 331820  2015-08-20 14:24:47          10123      Operational
# 1065835 2015-08-20 17:47:28          10123      Operational
# 1065839 2015-08-20 17:47:22          10123      Operational
# 1065843 2015-08-20 17:47:20          10123      Operational
# 1065847 2015-08-20 17:47:18          10123      Operational
# 1065851 2015-08-20 17:47:15          10123      Operational
# 1065855 2015-08-20 17:47:09          10123      Operational
# 1065859 2015-08-20 17:47:07          10123      Operational
# 1065863 2015-08-20 17:46:58          10123      Operational
# 1065867 2015-08-20 17:46:47          10123      Operational
# 1065871 2015-08-20 17:46:46          10123      Operational
# 1065875 2015-08-20 17:46:44          10123      Operational
# ...

# %%
# Überprüfe, ob message 10122 auch zu Kategorei Information gehört

X.loc[X['message_number'] == '10122', "message_severity"].unique()
# Out:
# array(['Information', 'Programm gestoppt'], dtype=object)

# %%
X[X.message_number == '10122'][X.message_severity == 'Programm gestoppt'] # -> 32  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 341731  2015-08-24 06:38:41          10122      Operational
# 654779  2015-08-18 16:15:27          10122      Operational
# 1118290 2015-08-24 07:22:33          10122      Operational
# 3005566 2015-10-20 20:04:08          10122      Operational
# 3005573 2015-10-20 20:03:30          10122      Operational
# 3095030 2015-10-22 10:01:46          10122      Operational
# 3739877 2015-09-09 04:39:58          10122      Operational
# 3771201 2015-12-16 18:17:21          10122      Operational
# 3771599 2015-12-16 18:40:53          10122      Operational
# 3771629 2015-12-16 18:43:55          10122      Operational
# 3772050 2015-12-16 18:53:00          10122      Operational
# 3772293 2015-12-16 18:58:57          10122      Operational
# ...

# %%
# Überprüfe, ob message 10130 auch zu Kategorei Information gehört

X.loc[X['message_number'] == '10130', "message_severity"].unique()
# Out:
# array(['Information', 'Programm gestoppt'], dtype=object)

# %%
X[X.message_number == '10130'][X.message_severity == 'Programm gestoppt'] # -> 211  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 341747  2015-08-24 06:36:34          10130      Operational
# 341755  2015-08-24 06:36:30          10130      Operational
# 341759  2015-08-24 06:36:27          10130      Operational
# 341767  2015-08-24 06:36:10          10130      Operational
# 341781  2015-08-24 06:35:28          10130      Operational
# 341819  2015-08-24 06:28:31          10130      Operational
# 646832  2015-08-17 18:49:23          10130      Operational
# 646836  2015-08-17 18:49:16          10130      Operational
# 646840  2015-08-17 18:49:11          10130      Operational
# 646850  2015-08-17 18:48:36          10130      Operational
# 646854  2015-08-17 18:48:08          10130      Operational
# 646858  2015-08-17 18:47:58          10130      Operational
# ...

# %%
# Überprüfe, ob message 10126 auch zu Kategorei Information gehört

X.loc[X['message_number'] == '10126', "message_severity"].unique()
# Out:
# array(['Information', 'Programm gestoppt'], dtype=object)

# %%
X[X.message_number == '10126'][X.message_severity == 'Programm gestoppt'] # -> 3  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 654251  2015-08-18 09:53:42          10126      Operational
# 3795072 2015-08-21 02:32:36          10126      Operational
# 3795354 2015-08-21 02:04:02          10126      Operational
#
#           message_severity an_title an_description  an_line  an_cell  \
# 654251   Programm gestoppt      NaN            NaN  line_11  cell_11
# 3795072  Programm gestoppt      NaN            NaN  line_23  cell_11
# 3795354  Programm gestoppt      NaN            NaN  line_23  cell_11
#
#           an_robot
# 654251    robot_66
# 3795072  robot_172
# 3795354  robot_172

# %%
# Überprüfe, ob message 10129 auch zu Kategorei Information gehört

X.loc[X['message_number'] == '10129', "message_severity"].unique()
# Out:
# array(['Information', 'Programm gestoppt'], dtype=object)

# %%
X[X.message_number == '10129'][X.message_severity == 'Programm gestoppt'] # -> 58  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 2967770 2015-08-19 19:11:16          10129      Operational
# 3236671 2015-08-26 18:38:51          10129      Operational
# 3236764 2015-08-26 18:43:42          10129      Operational
# 3237035 2015-08-26 00:39:28          10129      Operational
# 3237426 2015-08-26 18:42:17          10129      Operational
# 3238762 2015-08-26 18:39:08          10129      Operational
# 3240390 2015-08-26 18:44:16          10129      Operational
# 3241444 2015-08-26 18:44:13          10129      Operational
# 3242429 2015-08-26 18:43:47          10129      Operational
# 3243478 2015-08-26 18:44:29          10129      Operational
# 3668860 2015-08-20 23:51:23          10129      Operational
# 3669010 2015-08-20 23:53:05          10129      Operational
# ...

# %%
# Überprüfe, ob message 10133 auch zu Kategorei Information gehört

X.loc[X['message_number'] == '10133', "message_severity"].unique()
# Out:
# array(['Information', 'Programm gestoppt'], dtype=object)

# %%
X[X.message_number == '10133'][X.message_severity == 'Programm gestoppt'] # -> 1  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3873596 2015-10-12 01:43:27          10133      Operational
#
#           message_severity an_title an_description  an_line  an_cell  \
# 3873596  Programm gestoppt      NaN            NaN  line_24  cell_14
#
#           an_robot
# 3873596  robot_179

# %%
# => können alle auf einmal ersetzt werden

# %% [markdown]
# # Ersetzen von allen 'Programm gestoppt' und überprüfen

# %%
# Ersetze alle 'Programm gestoppt' durch 'Information'
df1['message_severity'] = df1.message_severity.replace({'Programm gestoppt': 'Information'})

# Überprüfe message_severity von message_number=10129
df1.loc[df1['message_number'] == '10129', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %%
# Überprüfe message_severity von message_number=10123
df1.loc[df1['message_number'] == '10123', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %%
# Überprüfe message_severity von message_number=10125
df1.loc[df['message_number'] == '10125', "message_severity"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-a4b9f9c4e649> in <module>()
#       1 # Überprüfe message_severity von message_number=10125
# ----> 2 df1.loc[df['message_number'] == '10125', "message_severity"].unique()
#
# NameError: name 'df' is not defined

# %%
# Überprüfe message_severity von message_number=10122
df1.loc[df['message_number'] == '10122', "message_severity"].unique()

# %%
# Überprüfe message_severity von message_number=10130
df1.loc[df['message_number'] == '10130', "message_severity"].unique()

# %%
# Überprüfe message_severity von message_number=10133
df1.loc[df1['message_number'] == '10133', "message_severity"].unique()

# %%
# Überprüfe message_severity von message_number=10126
df1.loc[df1['message_number'] == '10126', "message_severity"].unique()

# %%
# Überprüfe message_severity von message number=10131

X.loc[X['message_number'] == '10131', "message_severity"].unique()

# %%
# Überprüfe message_severity von message number=10121

X.loc[X['message_number'] == '10121', "message_severity"].unique()

# %% [markdown]
# # message_number=10150

# %%
# Überprüfe message_severity von message number=10150

X.loc[X['message_number'] == '10150', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10150 andere message_numbers gibt, welche auch  'Programm gestartet' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Programm gestartet', "message_number"].unique()

# %%
X[X.message_number == '10150'][X.message_severity == 'Programm gestartet'] # -> 216  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Programm gestartet': 'Information'})

# Überprüfe message_severity von message_number=10150
df1.loc[df1['message_number'] == '10150', "message_severity"].unique()

# %% [markdown]
# # message_number=10002

# %%
# Überprüfe message_severity von message number=10002

X.loc[X['message_number'] == '10002', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10002 andere message_numbers gibt, welche auch  'Programmzeiger wurde zurückgesetzt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Programmzeiger wurde zurückgesetzt', "message_number"].unique()

# %%
X[X.message_number == '10002'][X.message_severity == 'Programmzeiger wurde zurückgesetzt'] # -> 397  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Programmzeiger wurde zurückgesetzt': 'Information'})

# Überprüfe message_severity von message_number=10002
df1.loc[df1['message_number'] == '10002', "message_severity"].unique()

# %% [markdown]
# # message_number=50024

# %%
# Überprüfe message_severity von message number=50024

X.loc[X['message_number'] == '50024', "message_severity"].unique()

# %%
# Überprüfe ob es außer 50024 andere message_numbers gibt, welche auch  'Zonenbahn-Fehler ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Zonenbahn-Fehler ', "message_number"].unique()

# %%
X[X.message_number == '50024'][X.message_severity == 'Zonenbahn-Fehler '] # -> 163587  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Zonenbahn-Fehler ': 'Warning'})

# Überprüfe message_severity von message_number=50024
df1.loc[df1['message_number'] == '50024', "message_severity"].unique()

# %% [markdown]
# # message_number=10155

# %%
# Überprüfe message_severity von message number=10155

X.loc[X['message_number'] == '10155', "message_severity"].unique()

# %%
X[X.message_number == '10155'][X.message_severity == 'Programm neu gestartet'] # -> 57  mal falsch zugeordnet

# %%
# Überprüfe ob es außer 10155 andere message_numbers gibt, welche auch  'Programm neu gestartet' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Programm neu gestartet', "message_number"].unique()

# %%
# Überprüfe message_severity von message number=10156

X.loc[X['message_number'] == '10156', "message_severity"].unique()

# %%
X[X.message_number == '10156'][X.message_severity == 'Programm neu gestartet'] # -> 11829  mal falsch zugeordnet

# %%
# Überprüfe message_severity von message number=10157

X.loc[X['message_number'] == '10157', "message_severity"].unique()
#-> mann kann alle drei: 10156, 10155, 10157 umwandeln

# %%
X[X.message_number == '10157'][X.message_severity == 'Programm neu gestartet'] # ->  1 mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Programm neu gestartet': 'Information'})

# Überprüfe message_severity von message_number=10155
df1.loc[df['message_number'] == '10155', "message_severity"].unique()

# %%
# Überprüfe message_severity von message_number=10156
df1.loc[df1['message_number'] == '10156', "message_severity"].unique()

# %%
# Überprüfe message_severity von message_number=10157
df1.loc[df1['message_number'] == '10157', "message_severity"].unique()

# %% [markdown]
# # message_number=71201

# %%
# Überprüfe message_severity von message number=71201

X.loc[X['message_number'] == '71201', "message_severity"].unique()

# %% [markdown]
# # message_number=10045

# %%
# Überprüfe message_severity von message number=10045

X.loc[X['message_number'] == '10045', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10045 andere message_numbers gibt, welche auch  'System neu gestartet' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'System neu gestartet', "message_number"].unique()

# %%
X[X.message_number == '10045'][X.message_severity == 'System neu gestartet'] # -> 58  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'System neu gestartet': 'Information'})

# Überprüfe message_severity von message_number=10045
df1.loc[df1['message_number'] == '10045', "message_severity"].unique()

# %% [markdown]
# # message_number=10151

# %%
# Überprüfe message_severity von message number=10151

X.loc[X['message_number'] == '10151', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10151 andere message_numbers gibt, welche auch  'Programm gestartet. ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Programm gestartet.', "message_number"].unique()
#-> können alle umgewndelt werden

# %%
X[X.message_number == '10151'][X.message_severity == 'Programm gestartet.'] # -> 162  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Programm gestartet.': 'Information'})

# Überprüfe message_severity von message_number=10151
df1.loc[df1['message_number'] == '10151', "message_severity"].unique()

# %% [markdown]
# # message_number=10053

# %%
# Überprüfe message_severity von message number=10053

X.loc[X['message_number'] == '10053', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10053 andere message_numbers gibt, welche auch  'Wiederanfahren fertig' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Wiederanfahren fertig', "message_number"].unique()

# %%
X[X.message_number == '10053'][X.message_severity == 'Wiederanfahren fertig'] # ->  11909  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Wiederanfahren fertig': 'Information'})

# Überprüfe message_severity von message_number=10153
df1.loc[df1['message_number'] == '10053', "message_severity"].unique()

# %% [markdown]
# # message_number=10052

# %%
# Überprüfe message_severity von message number=10052

X.loc[X['message_number'] == '10052', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10052 andere message_numbers gibt, welche auch  'Wiederanfahren gestartet' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Wiederanfahren gestartet', "message_number"].unique()

# %%
X[X.message_number == '10052'][X.message_severity == 'Wiederanfahren gestartet'] # ->  11907  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Wiederanfahren gestartet': 'Information'})

# Überprüfe message_severity von message_number=10052
df1.loc[df1['message_number'] == '10052', "message_severity"].unique()

# %% [markdown]
# # message_number=20205

# %%
# Überprüfe message_severity von message number=20205

X.loc[X['message_number'] == '20205', "message_severity"].unique()

# %%
# Überprüfe ob es außer 20205 andere message_numbers gibt, welche auch  'Automatik-Sicherheitshalt offen' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Automatik-Sicherheitshalt offen', "message_number"].unique()

# %%
X[X.message_number == '20205'][X.message_severity == 'Automatik-Sicherheitshalt offen'] # ->  8761   mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Automatik-Sicherheitshalt offen': 'Error'})

# Überprüfe message_severity von message_number=20205
df1.loc[df1['message_number'] == '20205', "message_severity"].unique()

# %% [markdown]
# # message_number=10232

# %%
# Überprüfe message_severity von message number=10232

X.loc[X['message_number'] == '10232', "message_severity"].unique()

# %%
X[X.message_number == '10232'][X.message_severity == 'Backup-Schritt fertig'] # ->  1233  mal falsch zugeordnet

# %%
# Überprüfe ob es außer 10232 andere message_numbers gibt, welche auch  'Backup-Schritt fertig' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Backup-Schritt fertig', "message_number"].unique()

# %%
# Überprüfe message_severity von message number=10230

X.loc[X['message_number'] == '10230', "message_severity"].unique()

# %%
X[X.message_number == '10230'][X.message_severity == 'Backup-Schritt fertig'] # -> 1233    mal falsch zugeordnet

# %%
# Überprüfe message_severity von message number=10231

X.loc[X['message_number'] == '10231', "message_severity"].unique()

# %%
X[X.message_number == '10231'][X.message_severity == 'Backup-Schritt fertig'] # ->  1233  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Backup-Schritt fertig': 'Information'})

# Überprüfe message_severity von message_number=10232
df1.loc[df1['message_number'] == '10232', "message_severity"].unique()

# %%
df1.loc[df1['message_number'] == '10230', "message_severity"].unique()

# %%
df1.loc[df1['message_number'] == '10231', "message_severity"].unique()

# %% [markdown]
# # message_number=50036

# %%
# Überprüfe message_severity von message number=50036

X.loc[X['message_number'] == '50036', "message_severity"].unique()

# %% [markdown]
# # message_number=50050

# %%
# Überprüfe message_severity von message number=50050

X.loc[X['message_number'] == '50050', "message_severity"].unique()

# %% [markdown]
# # message_number=10020

# %%
# Überprüfe message_severity von message number=10020

X.loc[X['message_number'] == '10020', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10020 andere message_numbers gibt, welche auch  'Status Abarbeitungsfehler' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Status Abarbeitungsfehler', "message_number"].unique()

# %%
X[X.message_number == '10020'][X.message_severity == 'Status Abarbeitungsfehler'] # ->  7  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Status Abarbeitungsfehler': 'Information'})

# Überprüfe message_severity von message_number=10020
df1.loc[df1['message_number'] == '10020', "message_severity"].unique()

# %% [markdown]
# # message_number=50163

# %%
# Überprüfe message_severity von message number=50163

X.loc[X['message_number'] == '50163', "message_severity"].unique()

# %% [markdown]
# # message_number=100000

# %%
# Überprüfe message_severity von message number=100000

X.loc[X['message_number'] == '100000', "message_severity"].unique()

# %%
# Überprüfe ob es außer 100000 andere message_numbers gibt, welche auch  'Interner Fehler' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Interner Fehler', "message_number"].unique()

# %%
X[X.message_number == '100000'][X.message_severity == 'Interner Fehler'] # ->  11  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Interner Fehler': 'Error'})

# Überprüfe message_severity von message_number=100000
df1.loc[df1['message_number'] == '100000', "message_severity"].unique()

# %% [markdown]
# # message_number=20074

# %%
# Überprüfe message_severity von message number=20074

X.loc[X['message_number'] == '20074', "message_severity"].unique()

# %%
X[X.message_number == '20074'][X.message_severity == 'Befehl nicht zulässig'] # ->  18  mal falsch zugeordnet

# %%
# Überprüfe ob es außer 20074 andere message_numbers gibt, welche auch  'Befehl nicht zulässig' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Befehl nicht zulässig', "message_number"].unique()

# %%
# Überprüfe message_severity von message number=20072

X.loc[X['message_number'] == '20072', "message_severity"].unique()

# %%
X[X.message_number == '20072'][X.message_severity == 'Befehl nicht zulässig'] # ->  12  mal falsch zugeordnet

# %%
# Überprüfe message_severity von message number=20070???? --> soll Error sein

X.loc[X['message_number'] == '20070', "message_severity"].unique()

# %%
# Überprüfe message_severity von message number=20082

X.loc[X['message_number'] == '20082', "message_severity"].unique()

# %%
X[X.message_number == '20082'][X.message_severity == 'Befehl nicht zulässig'] # ->  3  mal falsch zugeordnet

# %%
# Überprüfe message_severity von message number=20061

X.loc[X['message_number'] == '20061', "message_severity"].unique()

# %%
X[X.message_number == '20061'][X.message_severity == 'Befehl nicht zulässig'] # ->  5  mal falsch zugeordnet

# %%
# Überprüfe message_severity von message number=20054

X.loc[X['message_number'] == '20054', "message_severity"].unique()
# --> können alle umgeandelt werden

# %%
X[X.message_number == '20054'][X.message_severity == 'Befehl nicht zulässig'] # -> 1   mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Befehl nicht zulässig': 'Error'})

# Überprüfe message_severity von message_number=20074
df1.loc[df1['message_number'] == '20074', "message_severity"].unique()

# %% [markdown]
# # message_number=20066

# %%
# Überprüfe message_severity von message number=20066

X.loc[X['message_number'] == '20066', "message_severity"].unique()

# %% [markdown]
# # message_number=20067

# %%
# Überprüfe message_severity von message number=20067

X.loc[X['message_number'] == '20067', "message_severity"].unique()

# %% [markdown]
# # message_number=20051

# %%
# Überprüfe message_severity von message number=20051

X.loc[X['message_number'] == '20051', "message_severity"].unique()

# %% [markdown]
# # message_number=20075

# %%
# Überprüfe message_severity von message number=20075

X.loc[X['message_number'] == '20075', "message_severity"].unique()

# %% [markdown]
# # message_number=20064

# %%
# Überprüfe message_severity von message number=20064

X.loc[X['message_number'] == '20064', "message_severity"].unique()

# %% [markdown]
# # message_number=10019

# %%
# Überprüfe message_severity von message number=10019

X.loc[X['message_number'] == '10019', "message_severity"].unique()

# %% [markdown]
# # message_number=10018

# %%
# Überprüfe message_severity von message number=10018

X.loc[X['message_number'] == '10018', "message_severity"].unique()

# %% [markdown]
# # message_number=80002

# %% [markdown]
# # Annahme: Um eine konsistente Zuordnung von jedem message_number nur zu einer bestimmten message_severity aufzubewahren, werden alle vorkommenden Titeln von message_number=80002 zu berets zugeordneten Warning zugeordnet.

# %%
# Überprüfe message_severity von message number=80002

X.loc[X['message_number'] == '80002', "message_severity"].unique()

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch  ' Schweißsteuerung Fehler!! ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Schweißsteuerung Fehler!! ', "message_number"].unique()

# %%
X[X.message_number == '80002'][X.message_severity == ' Schweißsteuerung Fehler!! '] # -> 79 mal falsch zugeordnet

# %%
# Ersetze die Kategorie
df1['message_severity'] = df1.message_severity.replace({' Schweißsteuerung Fehler!! ': 'Warning'})

# %%
X[X.message_number == '80002'][X.message_severity == 'Warning'] # ->  mal 26226 richtig zugeordnet

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch  ' Schweißzangen Fehler!! ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Schweißzangen Fehler!! ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Schweißzangen Fehler!! ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch  ' Warte auf Fraeser Umdrehungszaehler ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Fraeser Umdrehungszaehler ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Fraeser Umdrehungszaehler ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch  ' Warte auf E.-Kappe vorhanden ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf E.-Kappe vorhanden ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf E.-Kappe vorhanden ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch  ' Warte auf Kühlwasser!! ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Kühlwasser!! ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Kühlwasser!! ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch  ' Warte auf Schweißzangen Kraft Signal ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Schweißzangen Kraft Signal ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Schweißzangen Kraft Signal ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch  ' Warte auf Zange MotionCompl Signal ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Zange MotionCompl Signal ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Zange MotionCompl Signal ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch  ' Servozange FS1 Error: 18813 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Servozange FS1 Error: 18813 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Servozange FS1 Error: 18813 ': 'Warning'})

# %%
X[X.message_severity == 'NaN']

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Schweißzangen Motion/Ready Signal ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Schweißzangen Motion/Ready Signal ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Schweißzangen Motion/Ready Signal ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Kopf rueck muss low sein ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Kopf rueck muss low sein ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Kopf rueck muss low sein ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Kappe abgezogen ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Kappe abgezogen ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Kappe abgezogen ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Eingang Positionierbereit fehlt ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Eingang Positionierbereit fehlt ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Eingang Positionierbereit fehlt ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Eingang Kontakt muss low sein ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Eingang Kontakt muss low sein ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Eingang Kontakt muss low sein ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Falscher oder kein Bolzen ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Falscher oder kein Bolzen ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Falscher oder kein Bolzen ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf FK ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf FK ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf FK ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Schweisskopf muss rueck sein ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Schweisskopf muss rueck sein ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Schweisskopf muss rueck sein ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Bauteilkontrolle: -B04TK ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Bauteilkontrolle: -B04TK ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Bauteilkontrolle: -B04TK ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' HemQC: Kommunikationsfehler! ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' HemQC: Kommunikationsfehler! ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' HemQC: Kommunikationsfehler! ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Abdeckung Station 2 wird geschlossen. ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Abdeckung Station 2 wird geschlossen. ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Abdeckung Station 2 wird geschlossen. ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Abdeckung Station 1 wird geöffnet. ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Abdeckung Station 1 wird geöffnet. ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Abdeckung Station 1 wird geöffnet. ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Abdeckung Station 2 wird geöffnet. ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Abdeckung Station 2 wird geöffnet. ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Abdeckung Station 2 wird geöffnet. ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Abdeckung Station 1 wird geschlossen. ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Abdeckung Station 1 wird geschlossen. ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Abdeckung Station 1 wird geschlossen. ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' ' Station Belegt Meldung fehlt ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Station Belegt Meldung fehlt ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Station Belegt Meldung fehlt ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Kuehlwasser!! ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Kuehlwasser!! ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Kuehlwasser!! ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Schweißzange Kraft erreicht ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Schweißzange Kraft erreicht ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Schweißzange Kraft erreicht ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Wasser &lt' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Wasser &lt', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Wasser &lt': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B22V2 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B22V2 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B22V2 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B22V1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B22V1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B22V1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B12R1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B12R1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B12R1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B12V2 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B12V2 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B12V2 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte Bestätigung SPS Elektrodenwechsel fertig? ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte Bestätigung SPS Elektrodenwechsel fertig? ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte Bestätigung SPS Elektrodenwechsel fertig? ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Fehler bei IOEnable ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Fehler bei IOEnable ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Fehler bei IOEnable ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Unit nicht bereit ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Unit nicht bereit ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Unit nicht bereit ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Kein Kontakt zu EA Einheit ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Kein Kontakt zu EA Einheit ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Kein Kontakt zu EA Einheit ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Fehler bei IODisable ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Fehler bei IODisable ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Fehler bei IODisable ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Druckschalterüberwachung n.i.O ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Druckschalterüberwachung n.i.O ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Druckschalterüberwachung n.i.O ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B12V1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B12V1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B12V1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Schweißza. MotionCompl Signal ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Schweißza. MotionCompl Signal ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Schweißza. MotionCompl Signal ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Bauteilkontrolle: -B4TK ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Bauteilkontrolle: -B4TK ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Bauteilkontrolle: -B4TK ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Zangenfehler ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Zangenfehler ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Zangenfehler ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Festo Controller wird von einem anderen Client benutzt/ PC? ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Festo Controller wird von einem anderen Client benutzt/ PC? ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Festo Controller wird von einem anderen Client benutzt/ PC? ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Pal, Bauteilzaehler ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Pal, Bauteilzaehler ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Pal, Bauteilzaehler ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B11R1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B11R1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B11R1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B11V1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B11V1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B11V1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B13R1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B13R1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B13R1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Fehler bei Überprüfung ToolCode ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Fehler bei Überprüfung ToolCode ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Fehler bei Überprüfung ToolCode ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B17R1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B17R1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B17R1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B15V2 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B15V2 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B15V2 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B13V1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B13V1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B13V1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B15R1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B15R1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B15R1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B15V1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B15V1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B15V1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B15R2 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B15R2 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B15R2 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Bauteilkontrolle: -B1TK ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Bauteilkontrolle: -B1TK ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Bauteilkontrolle: -B1TK ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Servozange FS2 Error: 18813 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Servozange FS2 Error: 18813 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Servozange FS2 Error: 18813 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B13R2 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B13R2 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B13R2 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B13V2 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B13V2 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B13V2 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Bauteilkontrolle: -B3TK ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Bauteilkontrolle: -B3TK ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Bauteilkontrolle: -B3TK ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B16R1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B16R1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B16R1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Endlage: -B16V1 ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Endlage: -B16V1 ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Endlage: -B16V1 ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' LSP -Identischer Schweißpunkt! ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' LSP -Identischer Schweißpunkt! ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' LSP -Identischer Schweißpunkt! ': 'Warning'})

# %%
# Überprüfe ob es außer 80002 andere message_numbers gibt, welche auch ' Warte auf Schweißsteuerung Bereit Steuerteil ' als message_severity Kategorie haben

X.loc[X['message_severity'] == ' Warte auf Schweißsteuerung Bereit Steuerteil ', "message_number"].unique()

# %%
# Ersetze die vorhandene falsche Kategorie
df1['message_severity'] = df1.message_severity.replace({' Warte auf Schweißsteuerung Bereit Steuerteil ': 'Warning'})

# %% [markdown]
# # Überprüfe, ob die message_severity Korrektur von message_number=80002 erfolgreich war

# %%
# Überprüfe message_severity von message number=80002 in df1

df1.loc[df1['message_number'] == '80002', "message_severity"].unique() # -> alles erfolgreich korregiert

# %% [markdown]
# # message_number=50026

# %%
# Überprüfe message_severity von message number=50026

X.loc[X['message_number'] == '50026', "message_severity"].unique()

# %% [markdown]
# # message_number=10152

# %%
# Überprüfe message_severity von message number=10152

X.loc[X['message_number'] == '10152', "message_severity"].unique()

# %% [markdown]
# # message_number=10021

# %%
# Überprüfe message_severity von message number=10021

X.loc[X['message_number'] == '10021', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10021 andere message_numbers gibt, welche auch  'Rücksetzen Abarbeitungsfehler' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Rücksetzen Abarbeitungsfehler', "message_number"].unique()

# %%
X[X.message_number == '10021'][X.message_severity == 'Rücksetzen Abarbeitungsfehler'] # -> 6 mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Rücksetzen Abarbeitungsfehler': 'Information'})

# Überprüfe message_severity von message_number=10021
df1.loc[df1['message_number'] == '10021', "message_severity"].unique()

# %% [markdown]
# # message_number=10097

# %%
# Überprüfe message_severity von message number=10097

X.loc[X['message_number'] == '10097', "message_severity"].unique()

# %% [markdown]
# # message_number=50143

# %%
# Überprüfe message_severity von message number=50143

X.loc[X['message_number'] == '50143', "message_severity"].unique()

# %% [markdown]
# # message_number=20010

# %%
# Überprüfe message_severity von message number=20010

X.loc[X['message_number'] == '20010', "message_severity"].unique()

# %% [markdown]
# # message_number=10013

# %%
# Überprüfe message_severity von message number=10013

X.loc[X['message_number'] == '10013', "message_severity"].unique()

# %%
# Überprüfe ob es außer 10013 andere message_numbers gibt, welche auch  'Not-Aus-Status ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Not-Aus-Status ', "message_number"].unique()

# %%
X[X.message_number == '10013'][X.message_severity == 'Not-Aus-Status '] # -> 1 mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Not-Aus-Status ': 'Information'})

# Überprüfe message_severity von message_number=10013
df1.loc[df1['message_number'] == '10013', "message_severity"].unique()

# %% [markdown]
# # message_number=10084

# %%
# Überprüfe message_severity von message number=10084

X.loc[X['message_number'] == '10084', "message_severity"].unique()

# %% [markdown]
# # message_number=10048

# %%
# Überprüfe message_severity von message number=10048

X.loc[X['message_number'] == '10048', "message_severity"].unique()

# %% [markdown]
# # message_number=40228

# %%
# Überprüfe message_severity von message number=40228

X.loc[X['message_number'] == '40228', "message_severity"].unique()

# %%
# Überprüfe ob es außer 40228 andere message_numbers gibt, welche auch  'Abarbeitungsfehler' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Abarbeitungsfehler', "message_number"].unique()

# %%
X[X.message_number == '40228'][X.message_severity == 'Abarbeitungsfehler'] # -> 4  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Abarbeitungsfehler': 'Error'})

# Überprüfe message_severity von message_number=40228
df1.loc[df1['message_number'] == '40228', "message_severity"].unique()

# %% [markdown]
# # message_number=10253

# %%
# Überprüfe message_severity von message number=10253

X.loc[X['message_number'] == '10253', "message_severity"].unique()

# %% [markdown]
# # message_number=10252

# %%
# Überprüfe message_severity von message number=10252

X.loc[X['message_number'] == '10252', "message_severity"].unique()

# %% [markdown]
# # message_number=10251

# %%
# Überprüfe message_severity von message number=10251

X.loc[X['message_number'] == '10251', "message_severity"].unique()

# %% [markdown]
# # message_number=10250

# %%
# Überprüfe message_severity von message number=10250

X.loc[X['message_number'] == '10250', "message_severity"].unique()

# %% [markdown]
# # message_number=50316

# %%
# Überprüfe message_severity von message number=50316

X.loc[X['message_number'] == '50316', "message_severity"].unique()

# %%
# Überprüfe ob es außer 50316 andere message_numbers gibt, welche auch  'Absolutgenauigkeit nicht aktiviert' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Absolutgenauigkeit nicht aktiviert', "message_number"].unique()

# %%
X[X.message_number == '50316'][X.message_severity == 'Absolutgenauigkeit nicht aktiviert'] # -> 1  mal falsch zugeordnet

# %%
df1['message_severity'] = df1.message_severity.replace({'Absolutgenauigkeit nicht aktiviert': 'Warning'})

# Überprüfe message_severity von message_number=50316
df1.loc[df1['message_number'] == '50316', "message_severity"].unique()

# %% [markdown]
# # message_number=10046

# %%
# Überprüfe message_severity von message number=10046

X.loc[X['message_number'] == '10046', "message_severity"].unique()

# %% [markdown]
# # message_number=20206

# %%
# Überprüfe message_severity von message number=20206

X.loc[X['message_number'] == '20206', "message_severity"].unique()

# %%
# Überprüfe ob es außer 20206 andere message_numbers gibt, welche auch  'Allgemeiner Sicherheitshalt offen als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Allgemeiner Sicherheitshalt offen', "message_number"].unique()

# %%
X[X.message_number == '20206'][X.message_severity == 'Allgemeiner Sicherheitshalt offen'] # -> 116  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3237036 2015-08-26 00:39:25          20206           System
# 3672095 2015-08-21 05:09:17          20206           System
# 3672153 2015-08-21 00:57:32          20206           System
# 3672154 2015-08-21 00:53:39          20206           System
# 3672306 2015-08-21 05:11:16          20206           System
# 3672344 2015-08-21 00:59:31          20206           System
# 3672345 2015-08-21 00:55:37          20206           System
# 3672509 2015-08-21 05:13:06          20206           System
# 3672546 2015-08-21 01:01:21          20206           System
# 3672547 2015-08-21 00:57:27          20206           System
# 3672711 2015-08-21 05:09:51          20206           System
# 3672748 2015-08-21 00:58:07          20206           System
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Allgemeiner Sicherheitshalt offen': 'Error'})

# Überprüfe message_severity von message_number=20206
df1.loc[df1['message_number'] == '20206', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=71439

# %%
# Überprüfe message_severity von message number=71439

X.loc[X['message_number'] == '71439', "message_severity"].unique()
# Out:
# array(['Diagnose der Profinet-E/A-Einheit', 'Warning'], dtype=object)

# %%
# Überprüfe ob es außer 71439 andere message_numbers gibt, welche auch  'Diagnose der Profinet-E/A-Einheit' offen als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Diagnose der Profinet-E/A-Einheit', "message_number"].unique()
# Out:
# array(['71439'], dtype=object)

# %%
X[X.message_number == '71439'][X.message_severity == 'Diagnose der Profinet-E/A-Einheit'] # -> 3795 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3499    2015-05-08 12:35:32          71439  IOCommunication
# 7455    2015-05-08 12:35:25          71439  IOCommunication
# 7712    2015-05-08 12:11:48          71439  IOCommunication
# 8926    2015-05-08 12:11:41          71439  IOCommunication
# 9576    2015-05-08 11:13:09          71439  IOCommunication
# 11103   2015-05-08 11:09:50          71439  IOCommunication
# 11557   2015-05-08 11:09:43          71439  IOCommunication
# 13114   2015-05-08 11:05:44          71439  IOCommunication
# 13518   2015-05-08 11:05:38          71439  IOCommunication
# 14283   2015-05-08 11:00:03          71439  IOCommunication
# 14659   2015-05-08 10:59:56          71439  IOCommunication
# 16057   2015-05-08 10:57:42          71439  IOCommunication
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Diagnose der Profinet-E/A-Einheit': 'Warning'})

# Überprüfe message_severity von message_number=71439
df1.loc[df1['message_number'] == '71439', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=71518

# %%
# Überprüfe message_severity von message number=71518

X.loc[X['message_number'] == '71518', "message_severity"].unique()
# Out:
# array(['Warning', 'Profinet-Konfigurationskonflikt'], dtype=object)

# %%
# Überprüfe ob es außer 71518 andere message_numbers gibt, welche auch  'Profinet-Konfigurationskonflikt' offen als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Profinet-Konfigurationskonflikt', "message_number"].unique()
# Out:
# array(['71518'], dtype=object)

# %%
X[X.message_number == '71518'][X.message_severity == 'Profinet-Konfigurationskonflikt'] # -> 7322  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 869176  2015-05-08 19:32:53          71518  IOCommunication
# 869179  2015-05-08 17:39:51          71518  IOCommunication
# 869180  2015-05-08 17:35:50          71518  IOCommunication
# 869181  2015-05-08 17:30:07          71518  IOCommunication
# 869182  2015-05-08 17:21:46          71518  IOCommunication
# 869183  2015-05-08 17:16:23          71518  IOCommunication
# 869184  2015-05-08 16:19:32          71518  IOCommunication
# 869185  2015-05-08 16:14:16          71518  IOCommunication
# 869190  2015-05-08 15:55:43          71518  IOCommunication
# 869196  2015-05-08 14:26:21          71518  IOCommunication
# 869200  2015-05-08 13:35:49          71518  IOCommunication
# 869201  2015-05-08 12:57:24          71518  IOCommunication
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Profinet-Konfigurationskonflikt': 'Warning'})

# Überprüfe message_severity von message_number=71518
df1.loc[df1['message_number'] == '71518', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=50376 !!!!!!! ACHTUNG GLEICHZEITIG WARNING UND ERROR ZUGEORDNET!!!!!!

# %%
# Überprüfe message_severity von message number=50376

X.loc[X['message_number'] == '50376', "message_severity"].unique()
# Out:
# array(['Warning', 'Error'], dtype=object)

# %%
X[X.message_number == '50376'][X.message_severity == 'Warning'] # -> 213 mal zu Warning zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 4546    2016-06-25 09:49:54          50376           Motion          Warning
# 5603    2016-06-25 13:18:19          50376           Motion          Warning
# 5740    2016-06-25 12:31:07          50376           Motion          Warning
# 6083    2016-06-25 10:35:34          50376           Motion          Warning
# 6212    2016-06-25 09:37:56          50376           Motion          Warning
# 6256    2016-06-25 09:30:56          50376           Motion          Warning
# 6280    2016-06-25 09:27:26          50376           Motion          Warning
# 6367    2016-06-25 09:11:26          50376           Motion          Warning
# 6396    2016-06-25 09:04:59          50376           Motion          Warning
# ...

# %%
X[X.message_number == '50376'][X.message_severity == 'Error'] # -> 3 mal zu Error zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 2066280 2016-07-11 11:54:46          50376           Motion            Error
# 2066397 2016-07-11 11:55:54          50376           Motion            Error
# 2178899 2016-07-11 11:55:38          50376           Motion            Error
#
#         an_title an_description  an_line  an_cell   an_robot
# 2066280      NaN            NaN  line_17  cell_17  robot_136
# 2066397      NaN            NaN  line_17  cell_17  robot_133
# 2178899      NaN            NaN  line_18   cell_3  robot_135

# %% [markdown]
# # message_number=20314

# %%
# Überprüfe message_severity von message number=20314

X.loc[X['message_number'] == '20314', "message_severity"].unique()
# Out:
# array(['Warning', 'Überwachungsfehler Sicherheitskreis 2'], dtype=object)

# %%
# Überprüfe ob es außer 20314 andere message_numbers gibt, welche auch  'Überwachungsfehler Sicherheitskreis 2' offen als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Überwachungsfehler Sicherheitskreis 2', "message_number"].unique()
# Out:
# array(['20314'], dtype=object)

# %%
X[X.message_number == '20314'][X.message_severity == 'Überwachungsfehler Sicherheitskreis 2'] # -> 36  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 293605  2015-05-04 21:50:00          20314           System
# 341317  2015-08-24 20:50:38          20314           System
# 646406  2015-08-17 18:43:11          20314           System
# 869316  2015-05-08 21:34:23          20314           System
# 1032661 2015-08-18 07:19:26          20314           System
# 1032857 2015-08-18 22:43:24          20314           System
# 1042679 2015-05-19 15:53:07          20314           System
# 1046068 2015-08-19 13:37:03          20314           System
# 1076567 2015-05-21 07:54:45          20314           System
# 1076593 2015-05-21 14:13:04          20314           System
# 1094139 2015-05-22 10:22:41          20314           System
# 2788994 2015-10-13 21:57:07          20314           System
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Überwachungsfehler Sicherheitskreis 2': 'Warning'})

# Überprüfe message_severity von message_number=20314
df1.loc[df1['message_number'] == '20314', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=10270

# %%
# Überprüfe message_severity von message number=10270

X.loc[X['message_number'] == '10270', "message_severity"].unique()
# Out:
# array(['Information', 'Zyklische Bremsenüberprüfung durchgeführt'],
#       dtype=object)

# %%
# Überprüfe ob es außer 10270 andere message_numbers gibt, welche auch  'Zyklische Bremsenüberprüfung durchgeführt' offen als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Zyklische Bremsenüberprüfung durchgeführt', "message_number"].unique()
# Out:
# array(['10270'], dtype=object)

# %%
X[X.message_number == '10270'][X.message_severity == 'Zyklische Bremsenüberprüfung durchgeführt'] # -> 1298   mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 324402  2015-08-17 18:47:33          10270      Operational
# 324499  2015-08-17 18:47:45          10270      Operational
# 324579  2015-08-17 18:46:39          10270      Operational
# 324673  2015-08-17 18:50:08          10270      Operational
# 324762  2015-08-17 18:48:45          10270      Operational
# 324852  2015-08-17 18:49:45          10270      Operational
# 327218  2015-08-18 18:47:34          10270      Operational
# 327267  2015-08-18 18:47:45          10270      Operational
# 327315  2015-08-18 18:46:39          10270      Operational
# 327358  2015-08-18 18:50:10          10270      Operational
# 327408  2015-08-18 18:48:46          10270      Operational
# 327447  2015-08-18 18:49:46          10270      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Zyklische Bremsenüberprüfung durchgeführt': 'Information'})

# Überprüfe message_severity von message_number=10270
df1.loc[df1['message_number'] == '10270', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=10271

# %%
# Überprüfe message_severity von message number=10271

X.loc[X['message_number'] == '10271', "message_severity"].unique()
# Out:
# array(['Information', 'Cyclic Brake Check gestartet'], dtype=object)

# %%
# Überprüfe ob es außer 10271 andere message_numbers gibt, welche auch  'Cyclic Brake Check gestartet' offen als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Cyclic Brake Check gestartet', "message_number"].unique()
# Out:
# array(['10271'], dtype=object)

# %%
X[X.message_number == '10271'][X.message_severity == 'Cyclic Brake Check gestartet'] # ->  1296   mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 319813  2015-08-21 18:49:30          10271      Operational
# 321117  2015-08-23 18:48:53          10271      Operational
# 324403  2015-08-17 18:46:31          10271      Operational
# 324469  2015-08-17 18:46:42          10271      Operational
# 324580  2015-08-17 18:45:36          10271      Operational
# 324674  2015-08-17 18:49:05          10271      Operational
# 324763  2015-08-17 18:47:42          10271      Operational
# 324853  2015-08-17 18:48:42          10271      Operational
# 327219  2015-08-18 18:46:31          10271      Operational
# 327268  2015-08-18 18:46:43          10271      Operational
# 327316  2015-08-18 18:45:37          10271      Operational
# 327359  2015-08-18 18:49:07          10271      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Cyclic Brake Check gestartet': 'Information'})

# Überprüfe message_severity von message_number=10271
df1.loc[df1['message_number'] == '10271', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=71444 ACHTUNG GLEICHZEITIG ZU INFORMATION, WARNING UND 'Alarm der Profinet-E/A-Einheit' ZUGEORDNET!!!!!!

# %%
# Überprüfe message_severity von message number=71444

X.loc[X['message_number'] == '71444', "message_severity"].unique()
# Out:
# array(['Alarm der Profinet-E/A-Einheit', 'Information', 'Warning'],
#       dtype=object)

# %%
X[X.message_number == '71444'][X.message_severity == 'Alarm der Profinet-E/A-Einheit'] # -> 3853  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 7314    2015-05-08 12:35:25          71444  IOCommunication
# 7596    2015-05-08 12:11:48          71444  IOCommunication
# 8404    2015-05-08 12:11:41          71444  IOCommunication
# 9366    2015-05-08 11:13:09          71444  IOCommunication
# 10916   2015-05-08 11:09:50          71444  IOCommunication
# 11294   2015-05-08 11:09:43          71444  IOCommunication
# 12948   2015-05-08 11:05:44          71444  IOCommunication
# 13236   2015-05-08 11:05:38          71444  IOCommunication
# 13900   2015-05-08 11:00:03          71444  IOCommunication
# 14566   2015-05-08 10:59:56          71444  IOCommunication
# 15727   2015-05-08 10:57:42          71444  IOCommunication
# 16175   2015-05-08 10:57:36          71444  IOCommunication
# ...

# %%
X[X.message_number == '71444'][X.message_severity == 'Information'] # -> 59150 mal Information zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 16325   2016-05-02 20:27:35          71444  IOCommunication      Information
# 17471   2016-06-02 06:17:02          71444  IOCommunication      Information
# 21402   2016-03-03 14:30:47          71444  IOCommunication      Information
# 23557   2016-05-03 06:17:40          71444  IOCommunication      Information
# 30197   2016-04-04 18:32:51          71444  IOCommunication      Information
# 30223   2016-04-04 18:31:12          71444  IOCommunication      Information
# 30238   2016-04-04 18:28:57          71444  IOCommunication      Information
# 30245   2016-04-04 18:28:50          71444  IOCommunication      Information
# 30280   2016-04-04 18:25:56          71444  IOCommunication      Information
# ...

# %%
X[X.message_number == '71444'][X.message_severity == 'Warning'] # ->  150  mal zu Warning zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 228271  2016-08-01 16:02:12          71444  IOCommunication          Warning
# 385080  2015-11-12 11:39:32          71444  IOCommunication          Warning
# 804167  2016-03-02 18:21:53          71444  IOCommunication          Warning
# 823739  2015-09-03 06:37:02          71444  IOCommunication          Warning
# 872820  2015-10-08 12:57:08          71444  IOCommunication          Warning
# 879117  2016-02-09 10:35:55          71444  IOCommunication          Warning
# 899509  2015-11-10 05:22:26          71444  IOCommunication          Warning
# 909346  2016-04-11 09:08:54          71444  IOCommunication          Warning
# 909376  2016-04-11 08:51:57          71444  IOCommunication          Warning
# ...

# %% [markdown]
# # message_number=40538

# %%
# Überprüfe message_severity von message number=40538

X.loc[X['message_number'] == '40538', "message_severity"].unique()
# Out:
# array(['Warning', 'Max. Wartezeit abgelaufen'], dtype=object)

# %%
# Überprüfe ob es außer 40538 andere message_numbers gibt, welche auch  'Max. Wartezeit abgelaufen' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Max. Wartezeit abgelaufen', "message_number"].unique()
# Out:
# array(['40538'], dtype=object)

# %%
X[X.message_number == '40538'][X.message_severity == 'Max. Wartezeit abgelaufen'] # -> 1217   mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 291797  2015-06-04 21:30:02          40538          Program
# 291802  2015-06-04 20:25:03          40538          Program
# 291803  2015-06-04 21:29:32          40538          Program
# 291808  2015-06-04 18:31:38          40538          Program
# 291809  2015-06-04 14:34:18          40538          Program
# 293579  2015-05-04 21:56:00          40538          Program
# 293598  2015-05-04 21:56:00          40538          Program
# 293600  2015-05-04 21:53:00          40538          Program
# 293601  2015-05-04 21:52:00          40538          Program
# 293616  2015-05-05 11:50:00          40538          Program
# 293617  2015-05-05 10:03:00          40538          Program
# 293639  2015-05-04 22:01:00          40538          Program
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Max. Wartezeit abgelaufen': 'Warning'})

# Überprüfe message_severity von message_number=40538
df1.loc[df1['message_number'] == '40538', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=71414

# %%
# Überprüfe message_severity von message number=71414

X.loc[X['message_number'] == '71414', "message_severity"].unique()
# Out:
# array(['Warning', 'Gleichzeitige Änderungen des Signalwerts'],
#       dtype=object)

# %%
# Überprüfe ob es außer 71414 andere message_numbers gibt, welche auch  'Gleichzeitige Änderungen des Signalwerts' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Gleichzeitige Änderungen des Signalwerts', "message_number"].unique()
# Out:
# array(['71414'], dtype=object)

# %%
X[X.message_number == '71414'][X.message_severity == 'Gleichzeitige Änderungen des Signalwerts'] # -> 5   mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 2493142 2015-11-04 10:07:45          71414  IOCommunication
# 2537204 2015-10-06 11:58:59          71414  IOCommunication
# 3238231 2015-08-26 12:13:49          71414  IOCommunication
# 3663334 2015-08-19 10:45:56          71414  IOCommunication
# 3830728 2015-08-31 13:52:28          71414  IOCommunication
#
#                                  message_severity an_title an_description  \
# 2493142  Gleichzeitige Änderungen des Signalwerts      NaN            NaN
# 2537204  Gleichzeitige Änderungen des Signalwerts      NaN            NaN
# 3238231  Gleichzeitige Änderungen des Signalwerts      NaN            NaN
# 3663334  Gleichzeitige Änderungen des Signalwerts      NaN            NaN
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Gleichzeitige Änderungen des Signalwerts': 'Warning'})

# Überprüfe message_severity von message_number=71414
df1.loc[df1['message_number'] == '71414', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20481

# %%
# Überprüfe message_severity von message number=20481

X.loc[X['message_number'] == '20481', "message_severity"].unique()
# Out:
# array(['Warning', 'SC 1 - OVR aktiv ', 'SC 2 - OVR aktiv '], dtype=object)

# %%
# Überprüfe ob es außer 20481 andere message_numbers gibt, welche auch  'SC 1 - OVR aktiv ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 1 - OVR aktiv ', "message_number"].unique()
# Out:
# array(['20481'], dtype=object)

# %%
X[X.message_number == '20481'][X.message_severity == 'SC 1 - OVR aktiv '] # -> 263   mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 293604  2015-05-04 21:51:00          20481           System
# 293645  2015-05-04 21:58:00          20481           System
# 293686  2015-05-04 22:02:00          20481           System
# 295680  2015-05-06 20:44:00          20481           System
# 295712  2015-05-06 21:20:00          20481           System
# 295733  2015-05-06 21:24:00          20481           System
# 299084  2015-05-07 06:34:00          20481           System
# 299107  2015-05-07 06:30:00          20481           System
# 299114  2015-05-07 06:27:00          20481           System
# 324474  2015-08-17 23:30:46          20481           System
# 331830  2015-08-20 14:24:35          20481           System
# 331864  2015-08-20 14:04:00          20481           System
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 - OVR aktiv ': 'Warning'})

# Überprüfe message_severity von message_number=20481
df1.loc[df1['message_number'] == '20481', "message_severity"].unique()
# Out:
# array(['Warning', 'SC 2 - OVR aktiv '], dtype=object)

# %%
# Überprüfe ob es außer 20481 andere message_numbers gibt, welche auch  'SC 2 - OVR aktiv ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 2 - OVR aktiv ', "message_number"].unique()
# Out:
# array(['20481'], dtype=object)

# %%
X[X.message_number == '20481'][X.message_severity == 'SC 2 - OVR aktiv '] # ->  4  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1025849 2015-05-18 20:40:54          20481           System
# 1025852 2015-05-18 20:39:41          20481           System
# 1025855 2015-05-18 20:38:40          20481           System
# 1025895 2015-05-18 07:19:30          20481           System
#
#           message_severity an_title an_description an_line  an_cell  an_robot
# 1025849  SC 2 - OVR aktiv       NaN            NaN  line_4  cell_18  robot_91
# 1025852  SC 2 - OVR aktiv       NaN            NaN  line_4  cell_18  robot_91
# 1025855  SC 2 - OVR aktiv       NaN            NaN  line_4  cell_18  robot_91
# 1025895  SC 2 - OVR aktiv       NaN            NaN  line_4  cell_18  robot_91

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 2 - OVR aktiv ': 'Warning'})

# Überprüfe message_severity von message_number=20481
df1.loc[df1['message_number'] == '20481', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20140

# %%
# Überprüfe message_severity von message number=20140

X.loc[X['message_number'] == '20140', "message_severity"].unique()
# Out:
# array(['Warning', 'Motoren-EIN unzulässig'], dtype=object)

# %%
# Überprüfe ob es außer 20140 andere message_numbers gibt, welche auch  'Motoren-EIN unzulässig' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Motoren-EIN unzulässig', "message_number"].unique()
# Out:
# array(['20140'], dtype=object)

# %%
X[X.message_number == '20140'][X.message_severity == 'Motoren-EIN unzulässig'] # ->  253  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 324475  2015-08-17 23:30:46          20140           System
# 326897  2015-08-24 17:39:31          20140           System
# 331831  2015-08-20 14:24:35          20140           System
# 331863  2015-08-20 14:04:00          20140           System
# 341274  2015-08-24 21:45:03          20140           System
# 341418  2015-08-24 17:47:21          20140           System
# 341474  2015-08-24 17:30:12          20140           System
# 341737  2015-08-24 06:37:20          20140           System
# 341741  2015-08-24 06:36:56          20140           System
# 341833  2015-08-24 06:27:10          20140           System
# 646887  2015-08-17 18:43:10          20140           System
# 654244  2015-08-18 09:54:43          20140           System
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Motoren-EIN unzulässig': 'Warning'})

# Überprüfe message_severity von message_number=20140
df1.loc[df1['message_number'] == '20140', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20212

# %%
# Überprüfe message_severity von message number=20212

X.loc[X['message_number'] == '20212', "message_severity"].unique()
# Out:
# array(['Error', 'Zwei-Kanal-Fehler, Betriebskreis'], dtype=object)

# %%
# Überprüfe ob es außer 20212 andere message_numbers gibt, welche auch  'Zwei-Kanal-Fehler, Betriebskreis' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Zwei-Kanal-Fehler, Betriebskreis', "message_number"].unique()
# Out:
# array(['20212'], dtype=object)

# %%
X[X.message_number == '20212'][X.message_severity == 'Zwei-Kanal-Fehler, Betriebskreis'] # -> 8   mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 654912  2015-08-18 16:06:18          20212           System
# 868946  2015-05-08 20:44:36          20212           System
# 3771131 2015-11-16 01:57:20          20212           System
# 3772092 2015-12-16 18:51:19          20212           System
# 3772093 2015-12-16 18:51:18          20212           System
# 3772138 2015-12-16 18:50:30          20212           System
# 3873364 2015-10-12 02:11:17          20212           System
# 3928492 2015-11-25 02:24:47          20212           System
#
#                          message_severity an_title an_description  an_line  \
# 654912   Zwei-Kanal-Fehler, Betriebskreis      NaN            NaN  line_11
# 868946   Zwei-Kanal-Fehler, Betriebskreis      NaN            NaN   line_4
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Zwei-Kanal-Fehler, Betriebskreis': 'Error'})

# Überprüfe message_severity von message_number=20212
df1.loc[df1['message_number'] == '20212', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40210

# %%
# Überprüfe message_severity von message number=40210

X.loc[X['message_number'] == '40210', "message_severity"].unique()
# Out:
# array(['Warning', 'Interrupt aus Warteschlange entfernt'], dtype=object)

# %%
# Überprüfe ob es außer 40210 andere message_numbers gibt, welche auch  'Interrupt aus Warteschlange entfernt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Interrupt aus Warteschlange entfernt', "message_number"].unique()
# Out:
# array(['40210'], dtype=object)

# %%
X[X.message_number == '40210'][X.message_severity == 'Interrupt aus Warteschlange entfernt'] # ->  30  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 327205  2015-08-18 15:45:19          40210          Program
# 327223  2015-08-18 15:45:07          40210          Program
# 327320  2015-08-18 15:44:12          40210          Program
# 327363  2015-08-18 15:47:43          40210          Program
# 327413  2015-08-18 15:46:19          40210          Program
# 327453  2015-08-18 15:47:19          40210          Program
# 3092811 2015-10-22 09:35:31          40210          Program
# 3656541 2015-08-17 10:23:29          40210          Program
# 3656593 2015-08-17 13:46:07          40210          Program
# 3663361 2015-08-19 04:54:24          40210          Program
# 3669219 2015-08-20 13:30:37          40210          Program
# 3669477 2015-08-20 09:59:36          40210          Program
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Interrupt aus Warteschlange entfernt': 'Warning'})

# Überprüfe message_severity von message_number=40210
df1.loc[df1['message_number'] == '40210', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20211

# %%
# Überprüfe message_severity von message number=20211

X.loc[X['message_number'] == '20211', "message_severity"].unique()
# Out:
# array(['Error', 'Zweikanal-Fehler Sicherheitskreis'], dtype=object)

# %%
# Überprüfe ob es außer 20211 andere message_numbers gibt, welche auch  'Zweikanal-Fehler Sicherheitskreis' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Zweikanal-Fehler Sicherheitskreis', "message_number"].unique()
# Out:
# array(['20211'], dtype=object)

# %%
X[X.message_number == '20211'][X.message_severity == 'Zweikanal-Fehler Sicherheitskreis'] # -> 12   mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 336043  2015-05-22 19:28:24          20211           System
# 1025702 2015-05-18 07:53:38          20211           System
# 1042549 2015-05-19 08:18:08          20211           System
# 3725166 2015-11-05 20:27:08          20211           System
# 3743323 2015-09-10 04:07:20          20211           System
# 3761917 2015-12-14 05:33:25          20211           System
# 3771132 2015-11-16 01:57:20          20211           System
# 3772284 2015-12-16 18:59:07          20211           System
# 3792039 2015-11-20 21:30:40          20211           System
# 3882176 2015-09-14 07:50:45          20211           System
# 3882878 2015-09-14 22:17:22          20211           System
# 3928256 2015-09-25 16:04:27          20211           System
#
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Zweikanal-Fehler Sicherheitskreis': 'Error'})

# Überprüfe message_severity von message_number=20211
df1.loc[df1['message_number'] == '20211', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10025

# %%
# Überprüfe message_severity von message number=10025

X.loc[X['message_number'] == '10025', "message_severity"].unique()
# Out:
# array(['Information', 'Kollision bestätigt'], dtype=object)

# %%
# Überprüfe ob es außer 10025 andere message_numbers gibt, welche auch  'Kollision bestätigt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Kollision bestätigt', "message_number"].unique()
# Out:
# array(['10025'], dtype=object)

# %%
X[X.message_number == '10025'][X.message_severity == 'Kollision bestätigt'] # -> 19  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1065956 2015-08-20 17:39:16          10025      Operational
# 1118365 2015-08-24 06:59:01          10025      Operational
# 1118543 2015-08-24 06:30:13          10025      Operational
# 1118555 2015-08-24 06:26:59          10025      Operational
# 1118559 2015-08-24 06:26:32          10025      Operational
# 1118567 2015-08-24 06:25:17          10025      Operational
# 1118574 2015-08-24 06:24:35          10025      Operational
# 1118582 2015-08-24 06:24:15          10025      Operational
# 1118613 2015-08-24 06:21:35          10025      Operational
# 1118623 2015-08-24 06:21:19          10025      Operational
# 1118630 2015-08-24 06:14:05          10025      Operational
# 1118637 2015-08-24 06:13:46          10025      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Kollision bestätigt': 'Information'})

# Überprüfe message_severity von message_number=10025
df1.loc[df1['message_number'] == '10025', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=10026

# %%
# Überprüfe message_severity von message number=10026

X.loc[X['message_number'] == '10026', "message_severity"].unique()
# Out:
# array(['Information', 'Zurück auf Bahn'], dtype=object)

# %%
# Überprüfe ob es außer 10026 andere message_numbers gibt, welche auch  'Zurück auf Bahn' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Zurück auf Bahn', "message_number"].unique()
# Out:
# array(['10026'], dtype=object)

# %%
X[X.message_number == '10026'][X.message_severity == 'Zurück auf Bahn'] # -> 21  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 1065957 2015-08-20 17:39:05          10026      Operational  Zurück auf Bahn
# 1118370 2015-08-24 06:57:38          10026      Operational  Zurück auf Bahn
# 1118395 2015-08-24 06:30:13          10026      Operational  Zurück auf Bahn
# 1118556 2015-08-24 06:26:58          10026      Operational  Zurück auf Bahn
# 1118561 2015-08-24 06:26:32          10026      Operational  Zurück auf Bahn
# 1118568 2015-08-24 06:25:16          10026      Operational  Zurück auf Bahn
# 1118576 2015-08-24 06:24:32          10026      Operational  Zurück auf Bahn
# 1118584 2015-08-24 06:24:14          10026      Operational  Zurück auf Bahn
# 1118615 2015-08-24 06:21:34          10026      Operational  Zurück auf Bahn
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Zurück auf Bahn': 'Information'})

# Überprüfe message_severity von message_number=10026
df1.loc[df1['message_number'] == '10026', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=10024

# %%
# Überprüfe message_severity von message number=10024

X.loc[X['message_number'] == '10024', "message_severity"].unique()
# Out:
# array(['Information', 'Kollision erkannt'], dtype=object)

# %%
# Überprüfe ob es außer 10024 andere message_numbers gibt, welche auch  Kollision erkannt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Kollision erkannt', "message_number"].unique()
# Out:
# array(['10024'], dtype=object)

# %%
X[X.message_number == '10024'][X.message_severity == 'Kollision erkannt'] # -> 21  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1065959 2015-08-20 17:39:03          10024      Operational
# 1118374 2015-08-24 06:57:37          10024      Operational
# 1118500 2015-08-24 06:30:12          10024      Operational
# 1118557 2015-08-24 06:26:56          10024      Operational
# 1118562 2015-08-24 06:26:30          10024      Operational
# 1118569 2015-08-24 06:25:15          10024      Operational
# 1118577 2015-08-24 06:24:31          10024      Operational
# 1118585 2015-08-24 06:24:13          10024      Operational
# 1118616 2015-08-24 06:21:32          10024      Operational
# 1118627 2015-08-24 06:14:06          10024      Operational
# 1118634 2015-08-24 06:14:04          10024      Operational
# 1118650 2015-08-24 05:56:15          10024      Operational
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Kollision erkannt': 'Information'})

# Überprüfe message_severity von message_number=10024
df1.loc[df1['message_number'] == '10024', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=50204

# %%
# Überprüfe message_severity von message number=50204

X.loc[X['message_number'] == '50204', "message_severity"].unique()
# Out:
# array(['Error', 'Bewegungsüberwachung'], dtype=object)

# %%
# Überprüfe ob es außer 50204 andere message_numbers gibt, welche auch  'Bewegungsüberwachung' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Bewegungsüberwachung', "message_number"].unique()
# Out:
# array(['50204'], dtype=object)

# %%
X[X.message_number == '50204'][X.message_severity == 'Bewegungsüberwachung'] # -> 21 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1065960 2015-08-20 17:39:02          50204           Motion
# 1118376 2015-08-24 06:57:37          50204           Motion
# 1118544 2015-08-24 06:30:11          50204           Motion
# 1118558 2015-08-24 06:26:56          50204           Motion
# 1118563 2015-08-24 06:26:30          50204           Motion
# 1118570 2015-08-24 06:25:14          50204           Motion
# 1118578 2015-08-24 06:24:31          50204           Motion
# 1118586 2015-08-24 06:24:12          50204           Motion
# 1118617 2015-08-24 06:21:32          50204           Motion
# 1118628 2015-08-24 06:14:06          50204           Motion
# 1118635 2015-08-24 06:14:04          50204           Motion
# 1118651 2015-08-24 05:56:14          50204           Motion
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Bewegungsüberwachung': 'Error'})

# Überprüfe message_severity von message_number=50204
df1.loc[df1['message_number'] == '50204', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20224

# %%
# Überprüfe message_severity von message number=20224

X.loc[X['message_number'] == '20224', "message_severity"].unique()
# Out:
# array(['Error', 'Zustimmungsschalter-Konflikt '], dtype=object)

# %%
# Überprüfe ob es außer 20224 andere message_numbers gibt, welche auch  'Zustimmungsschalter-Konflikt ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Zustimmungsschalter-Konflikt ', "message_number"].unique()
# Out:
# array(['20224'], dtype=object)

# %%
X[X.message_number == '20224'][X.message_severity == 'Zustimmungsschalter-Konflikt '] # -> 4 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 654910  2015-08-18 16:06:18          20224           System
# 868945  2015-05-08 20:44:36          20224           System
# 3772090 2015-12-16 18:51:19          20224           System
# 3772136 2015-12-16 18:50:30          20224           System
#
#                       message_severity an_title an_description  an_line  \
# 654910   Zustimmungsschalter-Konflikt       NaN            NaN  line_11
# 868945   Zustimmungsschalter-Konflikt       NaN            NaN   line_4
# 3772090  Zustimmungsschalter-Konflikt       NaN            NaN  line_23
# 3772136  Zustimmungsschalter-Konflikt       NaN            NaN  line_23
#
#         an_cell   an_robot
# 654910   cell_3   robot_67
# 868945   cell_6   robot_13
# 3772090  cell_3  robot_168
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Zustimmungsschalter-Konflikt ': 'Error'})

# Überprüfe message_severity von message_number=20224
df1.loc[df1['message_number'] == '20224', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20225

# %%
# Überprüfe message_severity von message number=20225

X.loc[X['message_number'] == '20225', "message_severity"].unique()
# Out:
# array(['Error', 'Automatik-Sicherheitshalt-Konflikt'], dtype=object)

# %%
# Überprüfe ob es außer 20225 andere message_numbers gibt, welche auch  'Automatik-Sicherheitshalt-Konflikt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Automatik-Sicherheitshalt-Konflikt', "message_number"].unique()
# Out:
# array(['20225'], dtype=object)

# %%
X[X.message_number == '20225'][X.message_severity == 'Automatik-Sicherheitshalt-Konflikt'] # -> 3 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 654911  2015-08-18 16:06:18          20225           System
# 3772091 2015-12-16 18:51:19          20225           System
# 3772137 2015-12-16 18:50:30          20225           System
#
#                            message_severity an_title an_description  an_line  \
# 654911   Automatik-Sicherheitshalt-Konflikt      NaN            NaN  line_11
# 3772091  Automatik-Sicherheitshalt-Konflikt      NaN            NaN  line_23
# 3772137  Automatik-Sicherheitshalt-Konflikt      NaN            NaN  line_23
#
#         an_cell   an_robot
# 654911   cell_3   robot_67
# 3772091  cell_3  robot_168
# 3772137  cell_3  robot_168

# %%
df1['message_severity'] = df1.message_severity.replace({'Automatik-Sicherheitshalt-Konflikt': 'Error'})

# Überprüfe message_severity von message_number=20225
df1.loc[df1['message_number'] == '20225', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10068

# %%
# Überprüfe message_severity von message number=10068

X.loc[X['message_number'] == '10068', "message_severity"].unique()
# Out:
# array(['Warning', 'Starten von Programm'], dtype=object)

# %%
# Überprüfe ob es außer 10068 andere message_numbers gibt, welche auch  'Starten von Programm als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Starten von Programm', "message_number"].unique()
# Out:
# array(['10068'], dtype=object)

# %%
X[X.message_number == '10068'][X.message_severity == 'Starten von Programm'] # -> 10  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3095797 2015-10-22 09:52:33          10068      Operational
# 3095803 2015-10-22 09:51:51          10068      Operational
# 3761752 2015-12-14 21:55:21          10068      Operational
# 3792029 2015-11-20 21:31:11          10068      Operational
# 3792042 2015-11-20 21:30:37          10068      Operational
# 3862760 2015-09-10 21:55:23          10068      Operational
# 3863036 2015-09-10 21:54:34          10068      Operational
# 3863553 2015-09-10 21:53:59          10068      Operational
# 3923537 2015-11-24 07:39:24          10068      Operational
# 3923654 2015-11-24 07:26:08          10068      Operational
#
#              message_severity an_title an_description  an_line  an_cell  \
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Starten von Programm': 'Warning'})

# Überprüfe message_severity von message_number=10068
df1.loc[df1['message_number'] == '10068', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=40223

# %%
# Überprüfe message_severity von message number=40223

X.loc[X['message_number'] == '40223', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41795

# %%
# Überprüfe message_severity von message number=41795

X.loc[X['message_number'] == '41795', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20293

# %%
# Überprüfe message_severity von message number=20293

X.loc[X['message_number'] == '20293', "message_severity"].unique()
# Out:
# array(['Error', 'Angeforderte Aktion nicht möglich'], dtype=object)

# %%
# Überprüfe ob es außer 20293 andere message_numbers gibt, welche auch  'Angeforderte Aktion nicht möglich' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Angeforderte Aktion nicht möglich', "message_number"].unique()
# Out:
# array(['20293'], dtype=object)

# %%
X[X.message_number == '20293'][X.message_severity == 'Angeforderte Aktion nicht möglich'] # -> 6 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3923486 2015-11-24 11:20:16          20293           System
# 3931614 2015-11-26 09:35:21          20293           System
# 3931619 2015-11-26 09:32:37          20293           System
# 3934245 2015-11-27 06:51:34          20293           System
# 3934246 2015-11-27 06:51:32          20293           System
# 3934247 2015-11-27 06:51:31          20293           System
#
#                           message_severity an_title an_description  an_line  \
# 3923486  Angeforderte Aktion nicht möglich      NaN            NaN  line_24
# 3931614  Angeforderte Aktion nicht möglich      NaN            NaN  line_24
# 3931619  Angeforderte Aktion nicht möglich      NaN            NaN  line_24
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Angeforderte Aktion nicht möglich': 'Error'})

# Überprüfe message_severity von message_number=20293
df1.loc[df1['message_number'] == '20293', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50438

# %%
# Überprüfe message_severity von message number=50438

X.loc[X['message_number'] == '50438', "message_severity"].unique()
# Out:
# array(['Warning', 'Timeout der Motoren-AUS-Sequenz'], dtype=object)

# %%
# Überprüfe ob es außer 50438 andere message_numbers gibt, welche auch  'Timeout der Motoren-AUS-Sequenz' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Timeout der Motoren-AUS-Sequenz', "message_number"].unique()
# Out:
# array(['50438'], dtype=object)

# %%
X[X.message_number == '50438'][X.message_severity == 'Timeout der Motoren-AUS-Sequenz'] # -> 7 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1076574 2015-05-21 06:36:04          50438           Motion
# 1076575 2015-05-21 06:35:59          50438           Motion
# 3877337 2015-10-13 21:08:10          50438           Motion
# 3882929 2015-09-14 15:25:13          50438           Motion
# 3882931 2015-09-14 15:25:08          50438           Motion
# 3882932 2015-09-14 15:25:03          50438           Motion
# 3882933 2015-09-14 15:24:58          50438           Motion
#
#                         message_severity an_title an_description  an_line  \
# 1076574  Timeout der Motoren-AUS-Sequenz      NaN            NaN   line_4
# 1076575  Timeout der Motoren-AUS-Sequenz      NaN            NaN   line_4
# 3877337  Timeout der Motoren-AUS-Sequenz      NaN            NaN  line_24
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Timeout der Motoren-AUS-Sequenz': 'Warning'})

# Überprüfe message_severity von message_number=50438
df1.loc[df1['message_number'] == '50438', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20260

# %%
# Überprüfe message_severity von message number=20260

X.loc[X['message_number'] == '20260', "message_severity"].unique()
# Out:
# array(['Error', 'Statuskonflikt Betriebssteuerung, DRV1'], dtype=object)

# %%
# Überprüfe ob es außer 20260 andere message_numbers gibt, welche auch  'Statuskonflikt Betriebssteuerung, DRV1' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Statuskonflikt Betriebssteuerung, DRV1', "message_number"].unique()
# Out:
# array(['20260'], dtype=object)

# %%
X[X.message_number == '20260'][X.message_severity == 'Statuskonflikt Betriebssteuerung, DRV1'] # -> 3 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1076576 2015-05-21 06:35:57          20260           System
# 3877339 2015-10-13 21:08:07          20260           System
# 3882934 2015-09-14 15:24:55          20260           System
#
#                                message_severity an_title an_description  \
# 1076576  Statuskonflikt Betriebssteuerung, DRV1      NaN            NaN
# 3877339  Statuskonflikt Betriebssteuerung, DRV1      NaN            NaN
# 3882934  Statuskonflikt Betriebssteuerung, DRV1      NaN            NaN
#
#          an_line  an_cell   an_robot
# 1076576   line_4   cell_3   robot_87
# 3877339  line_24  cell_14  robot_179
# 3882934  line_24  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Statuskonflikt Betriebssteuerung, DRV1': 'Error'})

# Überprüfe message_severity von message_number=20260
df1.loc[df1['message_number'] == '20260', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20142

# %%
# Überprüfe message_severity von message number=20142

X.loc[X['message_number'] == '20142', "message_severity"].unique()
# Out:
# array(['Warning', 'Start unzulässig'], dtype=object)

# %%
# Überprüfe ob es außer 20142 andere message_numbers gibt, welche auch  'Start unzulässig' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Start unzulässig', "message_number"].unique()
# Out:
# array(['20390', '20142'], dtype=object)

# %%
X[X.message_number == '20142'][X.message_severity == 'Start unzulässig'] # -> 5  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  message_severity  \
# 345780  2015-06-26 05:37:11          20142           System  Start unzulässig
# 1060617 2015-05-20 13:37:28          20142           System  Start unzulässig
# 3862759 2015-09-10 21:55:23          20142           System  Start unzulässig
# 3863035 2015-09-10 21:54:34          20142           System  Start unzulässig
# 3863552 2015-09-10 21:53:59          20142           System  Start unzulässig
#
#         an_title an_description  an_line  an_cell   an_robot
# 345780       NaN            NaN   line_6  cell_11   robot_24
# 1060617      NaN            NaN   line_4   cell_3   robot_87
# 3862759      NaN            NaN  line_24  cell_17  robot_176
# 3863035      NaN            NaN  line_24  cell_17  robot_177
# ...

# %%
# Überprüfe, ob message 20390 auch zu Kategorei Information gehört

X.loc[X['message_number'] == '20390', "message_severity"].unique()
# Out:
# array(['Warning', 'Start unzulässig'], dtype=object)

# %%
X[X.message_number == '20390'][X.message_severity == 'Start unzulässig'] # ->  8 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  message_severity  \
# 341477  2015-08-24 17:29:50          20390           System  Start unzulässig
# 341478  2015-08-24 17:29:39          20390           System  Start unzulässig
# 341479  2015-08-24 17:29:38          20390           System  Start unzulässig
# 341480  2015-08-24 17:29:07          20390           System  Start unzulässig
# 341481  2015-08-24 17:28:08          20390           System  Start unzulässig
# 341482  2015-08-24 17:28:07          20390           System  Start unzulässig
# 3923437 2015-11-24 14:28:28          20390           System  Start unzulässig
# 3923485 2015-11-24 11:20:18          20390           System  Start unzulässig
#
#         an_title an_description  an_line  an_cell   an_robot
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Start unzulässig': 'Warning'})

# Überprüfe message_severity von message_number=20142
df1.loc[df1['message_number'] == '20142', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %%
df1.loc[df1['message_number'] == '20390', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=71276

# %%
# Überprüfe message_severity von message number=71276

X.loc[X['message_number'] == '71276', "message_severity"].unique()
# Out:
# array(['Information', 'Kommunikation mit E/A-Einheit aufgebaut'],
#       dtype=object)

# %%
# Überprüfe ob es außer 71276 andere message_numbers gibt, welche auch  'Kommunikation mit E/A-Einheit aufgebaut' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Kommunikation mit E/A-Einheit aufgebaut', "message_number"].unique()
# Out:
# array(['71276'], dtype=object)

# %%
X[X.message_number == '71276'][X.message_severity == 'Kommunikation mit E/A-Einheit aufgebaut'] # -> 29  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 654250  2015-08-18 09:53:47          71276  IOCommunication
# 654394  2015-08-18 06:46:21          71276  IOCommunication
# 654400  2015-08-18 05:54:53          71276  IOCommunication
# 654607  2015-08-18 05:53:45          71276  IOCommunication
# 655223  2015-08-18 05:54:42          71276  IOCommunication
# 1042655 2015-05-19 07:18:17          71276  IOCommunication
# 1060505 2015-05-20 19:29:14          71276  IOCommunication
# 1060547 2015-05-20 19:29:23          71276  IOCommunication
# 1060583 2015-05-20 09:06:05          71276  IOCommunication
# 1060596 2015-05-20 06:39:07          71276  IOCommunication
# 1067047 2015-08-20 17:08:10          71276  IOCommunication
# 1117656 2015-08-24 17:43:52          71276  IOCommunication
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Kommunikation mit E/A-Einheit aufgebaut': 'Information'})

# Überprüfe message_severity von message_number=71276
df1.loc[df1['message_number'] == '71276', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=71058

# %%
# Überprüfe message_severity von message number=71058

X.loc[X['message_number'] == '71058', "message_severity"].unique()
# Out:
# array(['Error', 'Keine Kommunikation mit E/A-Einheit'], dtype=object)

# %%
# Überprüfe ob es außer 71058 andere message_numbers gibt, welche auch  'Keine Kommunikation mit E/A-Einheit' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Keine Kommunikation mit E/A-Einheit', "message_number"].unique()
# Out:
# array(['71058', '71367'], dtype=object)

# %%
X[X.message_number == '71058'][X.message_severity == 'Keine Kommunikation mit E/A-Einheit'] # -> 29  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 654255  2015-08-18 09:53:42          71058  IOCommunication
# 654395  2015-08-18 06:46:16          71058  IOCommunication
# 654401  2015-08-18 05:54:48          71058  IOCommunication
# 654680  2015-08-18 05:53:40          71058  IOCommunication
# 655224  2015-08-18 05:54:37          71058  IOCommunication
# 1042656 2015-05-19 07:13:25          71058  IOCommunication
# 1060506 2015-05-20 19:29:09          71058  IOCommunication
# 1060548 2015-05-20 19:29:18          71058  IOCommunication
# 1060584 2015-05-20 09:06:00          71058  IOCommunication
# 1060602 2015-05-20 06:38:08          71058  IOCommunication
# 1067048 2015-08-20 17:08:05          71058  IOCommunication
# 1117657 2015-08-24 17:43:47          71058  IOCommunication
# ...

# %%
# Überprüfe message_severity von message number=71367

X.loc[X['message_number'] == '71367', "message_severity"].unique() # -> können beide umgewndelt werden
# Out:
# array(['Error', 'Keine Kommunikation mit E/A-Einheit'], dtype=object)

# %%
X[X.message_number == '71367'][X.message_severity == 'Keine Kommunikation mit E/A-Einheit'] # -> 7  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3794974 2015-08-21 03:03:07          71367  IOCommunication
# 3795163 2015-08-21 02:28:02          71367  IOCommunication
# 3795412 2015-08-21 01:58:06          71367  IOCommunication
# 3795463 2015-08-21 01:50:48          71367  IOCommunication
# 3795485 2015-08-21 01:25:19          71367  IOCommunication
# 3795507 2015-08-21 01:21:37          71367  IOCommunication
# 3795557 2015-08-21 01:01:09          71367  IOCommunication
#
#                             message_severity an_title an_description  an_line  \
# 3794974  Keine Kommunikation mit E/A-Einheit      NaN            NaN  line_23
# 3795163  Keine Kommunikation mit E/A-Einheit      NaN            NaN  line_23
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Keine Kommunikation mit E/A-Einheit': 'Error'})

# Überprüfe message_severity von message_number=71058
df1.loc[df1['message_number'] == '71058', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %%
# Überprüfe message_severity von message_number=71058
df1.loc[df1['message_number'] == '71367', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20216

# %%
# Überprüfe message_severity von message number=20216

X.loc[X['message_number'] == '20216', "message_severity"].unique()
# Out:
# array(['Error', 'Zustimmungsschalter im Automatikmodus aktiv'],
#       dtype=object)

# %%
# Überprüfe ob es außer 71276 andere message_numbers gibt, welche auch  'Zustimmungsschalter im Automatikmodus aktiv' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Zustimmungsschalter im Automatikmodus aktiv', "message_number"].unique()
# Out:
# array(['20216'], dtype=object)

# %%
X[X.message_number == '20216'][X.message_severity == 'Zustimmungsschalter im Automatikmodus aktiv'] # -> 11  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1076499 2015-05-21 07:53:59          20216           System
# 3739848 2015-09-09 04:56:34          20216           System
# 3873390 2015-10-12 02:09:16          20216           System
# 3873393 2015-10-12 02:09:07          20216           System
# 3873397 2015-10-12 02:08:59          20216           System
# 3876888 2015-10-13 23:29:26          20216           System
# 3915418 2015-10-21 06:39:53          20216           System
# 3915419 2015-10-21 06:39:30          20216           System
# 3922930 2015-09-24 13:59:06          20216           System
# 3922931 2015-09-24 13:58:58          20216           System
# 3922932 2015-09-24 13:58:25          20216           System
#
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Zustimmungsschalter im Automatikmodus aktiv': 'Error'})

# Überprüfe message_severity von message_number=20216
df1.loc[df1['message_number'] == '20216', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10128

# %%
# Überprüfe message_severity von message number=10128

X.loc[X['message_number'] == '10128', "message_severity"].unique()
# Out:
# array(['Warning', 'Rückwärts-Abarbeitung nicht möglich '], dtype=object)

# %%
# Überprüfe ob es außer 10128 andere message_numbers gibt, welche auch  'Rückwärts-Abarbeitung nicht möglich ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Rückwärts-Abarbeitung nicht möglich ', "message_number"].unique()
# Out:
# array(['10128'], dtype=object)

# %%
X[X.message_number == '10128'][X.message_severity == 'Rückwärts-Abarbeitung nicht möglich '] # ->  1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3923347 2015-11-24 16:57:25          10128      Operational
#
#                              message_severity an_title an_description  \
# 3923347  Rückwärts-Abarbeitung nicht möglich       NaN            NaN
#
#          an_line  an_cell   an_robot
# 3923347  line_24  cell_17  robot_176

# %%
df1['message_severity'] = df1.message_severity.replace({'Rückwärts-Abarbeitung nicht möglich ': 'Warning'})

# Überprüfe message_severity von message_number=10128
df1.loc[df1['message_number'] == '10128', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=50361

# %%
# Überprüfe message_severity von message number=50361

X.loc[X['message_number'] == '50361', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41581 ACHTUNG!!!!! WARNING UND ERROR PARALELL ZUGEORDNET

# %%
# Überprüfe message_severity von message number=41581

X.loc[X['message_number'] == '41581', "message_severity"].unique()
# Out:
# array(['Warning', 'Error'], dtype=object)

# %%
X[X.message_number == '41581'][X.message_severity == 'Error'] # -> 2 mal Warning zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 3358409 2016-03-03 15:04:27          41581          Program            Error
# 3367096 2016-02-08 10:18:48          41581          Program            Error
#
#         an_title an_description  an_line an_cell   an_robot
# 3358409      NaN            NaN  line_20  cell_4  robot_151
# 3367096      NaN            NaN  line_20  cell_4  robot_151

# %%
X[X.message_number == '41581'][X.message_severity == 'Warning'] # -> 188 mal Warning zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 224182  2016-05-31 05:00:32          41581          Program          Warning
# 224183  2016-05-31 04:59:21          41581          Program          Warning
# 224184  2016-05-31 04:58:11          41581          Program          Warning
# 224185  2016-05-31 04:57:00          41581          Program          Warning
# 224186  2016-05-31 04:55:50          41581          Program          Warning
# 224187  2016-05-31 04:54:39          41581          Program          Warning
# 224188  2016-05-31 04:53:28          41581          Program          Warning
# 224189  2016-05-31 04:52:18          41581          Program          Warning
# 224190  2016-05-31 04:51:07          41581          Program          Warning
# ...

# %% [markdown]
# # message_number=41595

# %%
# Überprüfe message_severity von message number=41595

X.loc[X['message_number'] == '41595', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=71521

# %%
# Überprüfe message_severity von message number=71521

X.loc[X['message_number'] == '71521', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=71520

# %%
# Überprüfe message_severity von message number=71520

X.loc[X['message_number'] == '71520', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # messge_number=20468

# %%
# Überprüfe message_severity von message number=20468

X.loc[X['message_number'] == '20468', "message_severity"].unique()
# Out:
# array(['Error', 'SC 1 - STZ-Überschreitung '], dtype=object)

# %%
# Überprüfe ob es außer 20468 andere message_numbers gibt, welche auch  'SC 1 - STZ-Überschreitung ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 1 - STZ-Überschreitung ', "message_number"].unique()
# Out:
# array(['20468'], dtype=object)

# %%
X[X.message_number == '20468'][X.message_severity == 'SC 1 - STZ-Überschreitung '] # ->  48 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3656320 2015-08-17 11:54:28          20468           System
# 3660302 2015-08-18 20:45:39          20468           System
# 3660308 2015-08-18 20:44:46          20468           System
# 3660327 2015-08-18 20:20:22          20468           System
# 3660363 2015-08-18 13:46:14          20468           System
# 3668861 2015-08-20 23:51:22          20468           System
# 3668882 2015-08-20 22:57:26          20468           System
# 3668901 2015-08-20 22:17:34          20468           System
# 3671980 2015-08-21 20:04:41          20468           System
# 3672144 2015-08-21 04:32:52          20468           System
# 3672147 2015-08-21 02:58:10          20468           System
# 3672148 2015-08-21 02:53:01          20468           System
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 - STZ-Überschreitung ': 'Error'})

# Überprüfe message_severity von message_number=20468
df1.loc[df1['message_number'] == '20468', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40160

# %%
# Überprüfe message_severity von message number=40160

X.loc[X['message_number'] == '40160', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20135

# %%
# Überprüfe message_severity von message number=20135

X.loc[X['message_number'] == '20135', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=71441

# %%
# Überprüfe message_severity von message number=71441

X.loc[X['message_number'] == '71441', "message_severity"].unique()
# Out:
# array(['Warning', 'Warnung zu Profinet-IO-Routing'], dtype=object)

# %%
# Überprüfe ob es außer 71441 andere message_numbers gibt, welche auch  'Warnung zu Profinet-IO-Routing' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Warnung zu Profinet-IO-Routing', "message_number"].unique()
# Out:
# array(['71441'], dtype=object)

# %%
X[X.message_number == '71441'][X.message_severity == 'Warnung zu Profinet-IO-Routing'] # ->  58 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 2967786 2015-08-19 19:10:46          71441  IOCommunication
# 3236681 2015-08-26 18:38:21          71441  IOCommunication
# 3237232 2015-08-26 18:38:38          71441  IOCommunication
# 3237761 2015-08-26 18:43:13          71441  IOCommunication
# 3238725 2015-08-26 00:38:59          71441  IOCommunication
# 3239337 2015-08-26 18:41:48          71441  IOCommunication
# 3240393 2015-08-26 18:43:47          71441  IOCommunication
# 3241457 2015-08-26 18:43:44          71441  IOCommunication
# 3242439 2015-08-26 18:43:18          71441  IOCommunication
# 3243481 2015-08-26 18:43:59          71441  IOCommunication
# 3668874 2015-08-20 23:50:55          71441  IOCommunication
# 3669026 2015-08-20 23:52:38          71441  IOCommunication
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Warnung zu Profinet-IO-Routing': 'Warning'})

# Überprüfe message_severity von message_number=71441
df1.loc[df1['message_number'] == '71441', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20200

# %%
# Überprüfe message_severity von message number=20200

X.loc[X['message_number'] == '20200', "message_severity"].unique()
# Out:
# array(['Error', 'Endlagenschalter von SC geöffnet'], dtype=object)

# %%
# Überprüfe ob es außer 20200 andere message_numbers gibt, welche auch  'Endlagenschalter von SC geöffnet' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Endlagenschalter von SC geöffnet', "message_number"].unique()
# Out:
# array(['20200'], dtype=object)

# %%
X[X.message_number == '20200'][X.message_severity == 'Endlagenschalter von SC geöffnet'] # ->  46 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3668862 2015-08-20 23:51:22          20200           System
# 3668876 2015-08-20 23:45:13          20200           System
# 3669013 2015-08-20 23:53:04          20200           System
# 3669148 2015-08-20 23:54:58          20200           System
# 3669275 2015-08-20 23:51:49          20200           System
# 3669384 2015-08-20 23:56:27          20200           System
# 3672156 2015-08-21 00:08:59          20200           System
# 3672159 2015-08-21 00:07:54          20200           System
# 3672355 2015-08-21 00:09:33          20200           System
# 3672558 2015-08-21 00:11:27          20200           System
# 3672759 2015-08-21 00:08:22          20200           System
# 3672965 2015-08-21 00:13:00          20200           System
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Endlagenschalter von SC geöffnet': 'Error'})

# Überprüfe message_severity von message_number=20200
df1.loc[df1['message_number'] == '20200', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50263 ACHTUNG!!!!! PARALELL ZU WARNING UND ERROR ZUGEORDNET!!!!!!!!!!

# %%
# Überprüfe message_severity von message number=50263

X.loc[X['message_number'] == '50263', "message_severity"].unique()
# Out:
# array(['Error', 'Warning'], dtype=object)

# %%
X[X.message_number == '50263'][X.message_severity == 'Warning'] # -> 1 mal Warning zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            event_timestamp message_number message_category message_severity  \
# 283556 2016-07-29 13:11:22          50263           Motion          Warning
#
#        an_title an_description an_line  an_cell  an_robot
# 283556      NaN            NaN  line_7  cell_12  robot_27

# %%
X[X.message_number == '50263'][X.message_severity == 'Error'] # -> 1 mal Error zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            event_timestamp message_number message_category message_severity  \
# 283544 2016-07-29 13:14:22          50263           Motion            Error
#
#        an_title an_description an_line  an_cell  an_robot
# 283544      NaN            NaN  line_7  cell_12  robot_27

# %% [markdown]
# # message_number=41555 ACHTUNG!!!!!! GLEICHZEITIG ZU WARNING UND ERROR ZUGEORDNET!!!!!

# %%
# Überprüfe message_severity von message number=41555

X.loc[X['message_number'] == '41555', "message_severity"].unique()
# Out:
# array(['Warning', 'Error', 'Kein Kontakt mit Einheit'], dtype=object)

# %%
# Überprüfe ob es außer 41555 andere message_numbers gibt, welche auch   'Kein Kontakt mit Einheit' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Kein Kontakt mit Einheit', "message_number"].unique()
# Out:
# array(['41555'], dtype=object)

# %%
X[X.message_number == '41555'][X.message_severity == 'Kein Kontakt mit Einheit'] # -> 93  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 654254  2015-08-18 09:53:42          41555          Program
# 1060600 2015-05-20 06:38:12          41555          Program
# 2427644 2015-11-02 15:51:06          41555          Program
# 2428093 2015-11-02 10:50:55          41555          Program
# 2457513 2015-11-03 16:13:06          41555          Program
# 2457786 2015-11-03 13:29:48          41555          Program
# 2457811 2015-11-03 13:18:55          41555          Program
# 2458021 2015-11-03 10:52:27          41555          Program
# 2458732 2015-11-03 13:10:37          41555          Program
# 2458845 2015-11-03 11:04:12          41555          Program
# 2459027 2015-11-03 08:35:36          41555          Program
# 2491635 2015-11-04 17:01:37          41555          Program
# ...

# %% [markdown]
# # message_number=10260

# %%
# Überprüfe message_severity von message number=10260

X.loc[X['message_number'] == '10260', "message_severity"].unique()
# Out:
# array(['Information', 'Systemdiagnose-Info generiert'], dtype=object)

# %%
# Überprüfe ob es außer 10260 andere message_numbers gibt, welche auch  'Systemdiagnose-Info generiert' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Systemdiagnose-Info generiert', "message_number"].unique()
# Out:
# array(['10260'], dtype=object)

# %%
X[X.message_number == '10260'][X.message_severity == 'Systemdiagnose-Info generiert'] # -> 1  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3873251 2015-10-12 11:49:09          10260      Operational
#
#                       message_severity an_title an_description  an_line  \
# 3873251  Systemdiagnose-Info generiert      NaN            NaN  line_24
#
#          an_cell   an_robot
# 3873251  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Systemdiagnose-Info generiert': 'Information'})

# Überprüfe message_severity von message_number=10260
df1.loc[df1['message_number'] == '10260', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=40502

# %%
# Überprüfe message_severity von message number=40502

X.loc[X['message_number'] == '40502', "message_severity"].unique()
# Out:
# array(['Warning', 'Abbruch durch digitalen Eingang'], dtype=object)

# %%
# Überprüfe ob es außer 40502 andere message_numbers gibt, welche auch  'Abbruch durch digitalen Eingang' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Abbruch durch digitalen Eingang', "message_number"].unique()
# Out:
# array(['40502'], dtype=object)

# %%
X[X.message_number == '40502'][X.message_severity == 'Abbruch durch digitalen Eingang'] # -> 2  mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3874001 2015-11-12 08:15:50          40502          Program
# 3874021 2015-11-12 07:35:25          40502          Program
#
#                         message_severity an_title an_description  an_line  \
# 3874001  Abbruch durch digitalen Eingang      NaN            NaN  line_24
# 3874021  Abbruch durch digitalen Eingang      NaN            NaN  line_24
#
#          an_cell   an_robot
# 3874001  cell_17  robot_178
# 3874021  cell_17  robot_178

# %%
df1['message_severity'] = df1.message_severity.replace({'Abbruch durch digitalen Eingang': 'Warning'})

# Überprüfe message_severity von message_number=40502
df1.loc[df1['message_number'] == '40502', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=50028

# %%
# Überprüfe message_severity von message number=50028

X.loc[X['message_number'] == '50028', "message_severity"].unique()
# Out:
# array(['Error', 'Bewegung in falsche Richtung'], dtype=object)

# %%
# Überprüfe ob es außer 50028 andere message_numbers gibt, welche auch  'Bewegung in falsche Richtung' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Bewegung in falsche Richtung', "message_number"].unique()
# Out:
# array(['50028'], dtype=object)

# %%
X[X.message_number == '50028'][X.message_severity == 'Bewegung in falsche Richtung'] # -> 17 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3765985 2015-11-15 09:18:59          50028           Motion
# 3766017 2015-11-15 10:03:53          50028           Motion
# 3766215 2015-11-15 11:40:36          50028           Motion
# 3766246 2015-11-15 11:26:50          50028           Motion
# 3766342 2015-11-15 11:56:24          50028           Motion
# 3856472 2015-11-08 09:18:13          50028           Motion
# 3856473 2015-11-08 09:18:07          50028           Motion
# 3856600 2015-11-08 11:13:48          50028           Motion
# 3877310 2015-10-13 21:09:42          50028           Motion
# 3877311 2015-10-13 21:09:36          50028           Motion
# 3892248 2015-11-16 09:51:46          50028           Motion
# 3892249 2015-11-16 09:51:38          50028           Motion
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Bewegung in falsche Richtung': 'Error'})

# Überprüfe message_severity von message_number=50028
df1.loc[df1['message_number'] == '50028', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20490

# %%
# Überprüfe message_severity von message number=20490

X.loc[X['message_number'] == '20490', "message_severity"].unique()
# Out:
# array(['OVR-Geschwindigkeit von SC 1 überschritten ', 'Error'],
#       dtype=object)

# %%
# Überprüfe ob es außer 20490 andere message_numbers gibt, welche auch  'OVR-Geschwindigkeit von SC 1 überschritten ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'OVR-Geschwindigkeit von SC 1 überschritten ', "message_number"].unique()
# Out:
# array(['20490'], dtype=object)

# %%
X[X.message_number == '20490'][X.message_severity == 'OVR-Geschwindigkeit von SC 1 überschritten '] # -> 22 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 295678  2015-05-06 20:46:00          20490           System
# 1118371 2015-08-24 06:57:38          20490           System
# 1118421 2015-08-24 06:52:14          20490           System
# 1118433 2015-08-24 06:50:22          20490           System
# 1118503 2015-08-24 06:37:30          20490           System
# 1118537 2015-08-24 06:31:55          20490           System
# 3727603 2015-11-06 08:44:22          20490           System
# 3748829 2015-09-11 02:05:36          20490           System
# 3786536 2015-10-19 06:17:28          20490           System
# 3795248 2015-08-21 02:12:35          20490           System
# 3860128 2015-09-09 21:51:21          20490           System
# 3876827 2015-10-13 23:35:43          20490           System
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'OVR-Geschwindigkeit von SC 1 überschritten ': 'Error'})

# Überprüfe message_severity von message_number=20490
df1.loc[df1['message_number'] == '20490', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=37001

# %%
# Überprüfe message_severity von message number=37001

X.loc[X['message_number'] == '37001', "message_severity"].unique()
# Out:
# array(['Error', 'Fehler beim Aktivieren des MOTOREN EIN-Schützes'],
#       dtype=object)

# %%
# Überprüfe ob es außer 37001 andere message_numbers gibt, welche auch  'Fehler beim Aktivieren des MOTOREN EIN-Schützes' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Fehler beim Aktivieren des MOTOREN EIN-Schützes', "message_number"].unique()
# Out:
# array(['37001'], dtype=object)

# %%
X[X.message_number == '37001'][X.message_severity == 'Fehler beim Aktivieren des MOTOREN EIN-Schützes'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1065933 2015-08-20 17:41:53          37001         Hardware
#
#                                         message_severity an_title  \
# 1065933  Fehler beim Aktivieren des MOTOREN EIN-Schützes      NaN
#
#         an_description an_line an_cell  an_robot
# 1065933            NaN  line_4  cell_6  robot_13

# %%
df1['message_severity'] = df1.message_severity.replace({'Fehler beim Aktivieren des MOTOREN EIN-Schützes': 'Error'})

# Überprüfe message_severity von message_number=37001
df1.loc[df1['message_number'] == '37001', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20485

# %%
# Überprüfe message_severity von message number=20485

X.loc[X['message_number'] == '20485', "message_severity"].unique()
# Out:
# array(['Warning', 'SC 1 - Bremsdrehmoment zu gering '], dtype=object)

# %%
# Überprüfe ob es außer 20485 andere message_numbers gibt, welche auch  'SC 1 - Bremsdrehmoment zu gering ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 1 - Bremsdrehmoment zu gering ', "message_number"].unique()
# Out:
# array(['20485'], dtype=object)

# %%
X[X.message_number == '20485'][X.message_severity == 'SC 1 - Bremsdrehmoment zu gering '] # -> 2 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3869005 2015-10-11 18:47:08          20485           System
#
#                           message_severity an_title an_description  an_line  \
# 3869005  SC 1 - Bremsdrehmoment zu gering       NaN            NaN  line_24
#
#          an_cell   an_robot
# 3869005  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 - Bremsdrehmoment zu gering ': 'Warning'})

# Überprüfe message_severity von message_number=20485
df1.loc[df1['message_number'] == '20485', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=10214

# %%
# Überprüfe message_severity von message number=10214

X.loc[X['message_number'] == '10214', "message_severity"].unique()
# Out:
# array(['Warning', 'Abarbeitung abgebrochen'], dtype=object)

# %%
# Überprüfe ob es außer 10214 andere message_numbers gibt, welche auch  'Abarbeitung abgebrochen' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Abarbeitung abgebrochen', "message_number"].unique()
# Out:
# array(['10214', '10217'], dtype=object)

# %%
X[X.message_number == '10214'][X.message_severity == 'Abarbeitung abgebrochen'] # -> 3 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3795478 2015-08-21 01:50:27          10214      Operational
# 3795498 2015-08-21 01:24:58          10214      Operational
# 3795521 2015-08-21 01:21:16          10214      Operational
#
#                 message_severity an_title an_description  an_line  an_cell  \
# 3795478  Abarbeitung abgebrochen      NaN            NaN  line_23  cell_11
# 3795498  Abarbeitung abgebrochen      NaN            NaN  line_23  cell_11
# 3795521  Abarbeitung abgebrochen      NaN            NaN  line_23  cell_11
#
#           an_robot
# 3795478  robot_172
# 3795498  robot_172
# 3795521  robot_172

# %% [markdown]
# # message_number=10217

# %%
# Überprüfe message_severity von message number=10217

X.loc[X['message_number'] == '10217', "message_severity"].unique()
# Out:
# array(['Warning', 'Abarbeitung abgebrochen'], dtype=object)

# %%
X[X.message_number == '10217'][X.message_severity == 'Abarbeitung abgebrochen'] # -> 2 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3877107 2015-10-13 22:29:50          10217      Operational
# 3877120 2015-10-13 22:47:55          10217      Operational
#
#                 message_severity an_title an_description  an_line  an_cell  \
# 3877107  Abarbeitung abgebrochen      NaN            NaN  line_24  cell_14
# 3877120  Abarbeitung abgebrochen      NaN            NaN  line_24  cell_14
#
#           an_robot
# 3877107  robot_179
# 3877120  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Abarbeitung abgebrochen': 'Warning'})

# Überprüfe message_severity von message_number=10214
df1.loc[df1['message_number'] == '10214', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %%
# Überprüfe message_severity von message_number=10214
df1.loc[df1['message_number'] == '10217', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20466

# %%
# Überprüfe message_severity von message number=20466

X.loc[X['message_number'] == '20466', "message_severity"].unique()
# Out:
# array(['Error', 'SC 1 - E/A-Fehler '], dtype=object)

# %%
# Überprüfe ob es außer 20466 andere message_numbers gibt, welche auch  'SC 1 - E/A-Fehler ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 1 - E/A-Fehler ', "message_number"].unique()
# Out:
# array(['20466'], dtype=object)

# %%
X[X.message_number == '20466'][X.message_severity == 'SC 1 - E/A-Fehler '] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3795457 2015-08-21 01:51:24          20466           System
#
#            message_severity an_title an_description  an_line  an_cell  \
# 3795457  SC 1 - E/A-Fehler       NaN            NaN  line_23  cell_11
#
#           an_robot
# 3795457  robot_172

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 - E/A-Fehler ': 'Error'})

# Überprüfe message_severity von message_number=20466
df1.loc[df1['message_number'] == '20466', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=71434

# %%
# Überprüfe message_severity von message number=71434

X.loc[X['message_number'] == '71434', "message_severity"].unique()
# Out:
# array(['Error', 'Profinet-Bus angehalten'], dtype=object)

# %%
# Überprüfe ob es außer 71434 andere message_numbers gibt, welche auch  'Profinet-Bus angehalten' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Profinet-Bus angehalten', "message_number"].unique()
# Out:
# array(['71434'], dtype=object)

# %%
X[X.message_number == '71434'][X.message_severity == 'Profinet-Bus angehalten'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3672573 2015-08-21 00:06:35          71434  IOCommunication
#
#                 message_severity an_title an_description  an_line an_cell  \
# 3672573  Profinet-Bus angehalten      NaN            NaN  line_22  cell_6
#
#           an_robot
# 3672573  robot_162

# %%
df1['message_severity'] = df1.message_severity.replace({'Profinet-Bus angehalten': 'Error'})

# Überprüfe message_severity von message_number=71434
df1.loc[df1['message_number'] == '71434', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=71431

# %%
# Überprüfe message_severity von message number=71431

X.loc[X['message_number'] == '71431', "message_severity"].unique()
# Out:
# array(['Error', 'Konfigurationsaktualisierung wird gerade ausgeführt'],
#       dtype=object)

# %%
# Überprüfe ob es außer 71431 andere message_numbers gibt, welche auch  'Konfigurationsaktualisierung wird gerade ausgeführt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Konfigurationsaktualisierung wird gerade ausgeführt', "message_number"].unique()
# Out:
# array(['71431'], dtype=object)

# %%
X[X.message_number == '71431'][X.message_severity == 'Konfigurationsaktualisierung wird gerade ausgeführt'] # -> 29 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 2967796 2015-08-19 19:07:51          71431  IOCommunication
# 3238729 2015-08-26 00:37:38          71431  IOCommunication
# 3668878 2015-08-20 23:44:56          71431  IOCommunication
# 3669028 2015-08-20 23:48:23          71431  IOCommunication
# 3669293 2015-08-20 23:48:50          71431  IOCommunication
# 3669403 2015-08-20 23:54:37          71431  IOCommunication
# 3672173 2015-08-21 00:05:47          71431  IOCommunication
# 3672371 2015-08-21 00:06:38          71431  IOCommunication
# 3672574 2015-08-21 00:06:23          71431  IOCommunication
# 3672980 2015-08-21 00:06:24          71431  IOCommunication
# 3739264 2015-09-09 03:22:02          71431  IOCommunication
# 3739269 2015-09-09 03:19:46          71431  IOCommunication
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Konfigurationsaktualisierung wird gerade ausgeführt': 'Error'})

# Überprüfe message_severity von message_number=71431
df1.loc[df1['message_number'] == '71431', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=71433

# %%
# Überprüfe message_severity von message number=71433

X.loc[X['message_number'] == '71433', "message_severity"].unique()
# Out:
# array(['Error', 'Kein Kontakt mit der Profinet-PCI-Karte'], dtype=object)

# %%
# Überprüfe ob es außer 71433 andere message_numbers gibt, welche auch  'Kein Kontakt mit der Profinet-PCI-Karte' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Kein Kontakt mit der Profinet-PCI-Karte', "message_number"].unique()
# Out:
# array(['71433'], dtype=object)

# %%
X[X.message_number == '71433'][X.message_severity == 'Kein Kontakt mit der Profinet-PCI-Karte'] # -> 35 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 2967797 2015-08-19 19:07:35          71433  IOCommunication
# 3238730 2015-08-26 00:37:22          71433  IOCommunication
# 3668879 2015-08-20 23:44:42          71433  IOCommunication
# 3669029 2015-08-20 23:48:10          71433  IOCommunication
# 3669295 2015-08-20 23:48:35          71433  IOCommunication
# 3669404 2015-08-20 23:54:20          71433  IOCommunication
# 3672174 2015-08-21 00:05:34          71433  IOCommunication
# 3672372 2015-08-21 00:06:26          71433  IOCommunication
# 3672575 2015-08-21 00:06:09          71433  IOCommunication
# 3672981 2015-08-21 00:06:09          71433  IOCommunication
# 3739243 2015-09-09 03:38:20          71433  IOCommunication
# 3739265 2015-09-09 03:21:32          71433  IOCommunication
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Kein Kontakt mit der Profinet-PCI-Karte': 'Error'})

# Überprüfe message_severity von message_number=71433
df1.loc[df1['message_number'] == '71433', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50037

# %%
# Überprüfe message_severity von message number=50037

X.loc[X['message_number'] == '50037', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20493

# %%
# Überprüfe message_severity von message number=20493

X.loc[X['message_number'] == '20493', "message_severity"].unique()
# Out:
# array(['Information', 'SC 1 - SBR ausgelöst '], dtype=object)

# %%
# Überprüfe ob es außer 20493 andere message_numbers gibt, welche auch  'SC 1 - SBR ausgelöst ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 1 - SBR ausgelöst ', "message_number"].unique()
# Out:
# array(['20493'], dtype=object)

# %%
X[X.message_number == '20493'][X.message_severity == 'SC 1 - SBR ausgelöst '] # -> 3 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3656319 2015-08-17 11:54:28          20493           System
# 3660326 2015-08-18 20:20:22          20493           System
# 3660362 2015-08-18 13:46:15          20493           System
#
#               message_severity an_title an_description  an_line an_cell  \
# 3656319  SC 1 - SBR ausgelöst       NaN            NaN  line_22  cell_6
# 3660326  SC 1 - SBR ausgelöst       NaN            NaN  line_22  cell_6
# 3660362  SC 1 - SBR ausgelöst       NaN            NaN  line_22  cell_6
#
#           an_robot
# 3656319  robot_165
# 3660326  robot_165
# 3660362  robot_165

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 - SBR ausgelöst ': 'Information'})

# Überprüfe message_severity von message_number=20493
df1.loc[df1['message_number'] == '20493', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=40191

# %%
# Überprüfe message_severity von message number=40191

X.loc[X['message_number'] == '40191', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=10401

# %%
# Überprüfe message_severity von message number=10401

X.loc[X['message_number'] == '10401', "message_severity"].unique()
# Out:
# array(['Information', 'Anwender Safety User abgemeldet'], dtype=object)

# %%
# Überprüfe ob es außer 10401 andere message_numbers gibt, welche auch  'Anwender Safety User abgemeldet' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Anwender Safety User abgemeldet', "message_number"].unique()
# Out:
# array(['10401'], dtype=object)

# %%
X[X.message_number == '10401'][X.message_severity == 'Anwender Safety User abgemeldet'] # -> 2 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739857 2015-09-09 04:41:23          10401      Operational
# 3876933 2015-10-13 23:18:51          10401      Operational
#
#                         message_severity an_title an_description  an_line  \
# 3739857  Anwender Safety User abgemeldet      NaN            NaN  line_23
# 3876933  Anwender Safety User abgemeldet      NaN            NaN  line_24
#
#          an_cell   an_robot
# 3739857   cell_3  robot_170
# 3876933  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Anwender Safety User abgemeldet': 'Information'})

# Überprüfe message_severity von message_number=10401
df1.loc[df1['message_number'] == '10401', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=20452

# %%
# Überprüfe message_severity von message number=20452

X.loc[X['message_number'] == '20452', "message_severity"].unique()
# Out:
# array(['Information', 'SC 1 synchronisiert '], dtype=object)

# %%
# Überprüfe ob es außer 20452 andere message_numbers gibt, welche auch  'SC 1 synchronisiert ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 1 synchronisiert ', "message_number"].unique()
# Out:
# array(['20452'], dtype=object)

# %%
X[X.message_number == '20452'][X.message_severity == 'SC 1 synchronisiert '] # -> 2 mal falsch zugeordne
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739880 2015-09-09 04:38:37          20452           System
# 3877041 2015-10-13 22:56:31          20452           System
#
#              message_severity an_title an_description  an_line  an_cell  \
# 3739880  SC 1 synchronisiert       NaN            NaN  line_23   cell_3
# 3877041  SC 1 synchronisiert       NaN            NaN  line_24  cell_14
#
#           an_robot
# 3739880  robot_170
# 3877041  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 synchronisiert ': 'Information'})

# Überprüfe message_severity von message_number=20452
df1.loc[df1['message_number'] == '20452', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=50428

# %%
# Überprüfe message_severity von message number=50428

X.loc[X['message_number'] == '50428', "message_severity"].unique()
# Out:
# array(['Information', 'SC Software-Synchronisierung begonnen'],
#       dtype=object)

# %%
# Überprüfe ob es außer 50428 andere message_numbers gibt, welche auch  'SC Software-Synchronisierung begonnen' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC Software-Synchronisierung begonnen', "message_number"].unique()
# Out:
# array(['50428'], dtype=object)

# %%
X[X.message_number == '50428'][X.message_severity == 'SC Software-Synchronisierung begonnen'] # -> 2 mal falsch zugeordne
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739881 2015-09-09 04:38:35          50428           Motion
# 3877042 2015-10-13 22:56:29          50428           Motion
#
#                               message_severity an_title an_description  \
# 3739881  SC Software-Synchronisierung begonnen      NaN            NaN
# 3877042  SC Software-Synchronisierung begonnen      NaN            NaN
#
#          an_line  an_cell   an_robot
# 3739881  line_23   cell_3  robot_170
# 3877042  line_24  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'SC Software-Synchronisierung begonnen': 'Information'})

# Überprüfe message_severity von message_number=50428
df1.loc[df1['message_number'] == '50428', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=20487

# %%
# Überprüfe message_severity von message number=20487

X.loc[X['message_number'] == '20487', "message_severity"].unique()
# Out:
# array(['Error', 'SC 1 - unsynchronisierte Geschwindigkeit überschritten '],
#       dtype=object)

# %%
# Überprüfe ob es außer 20487 andere message_numbers gibt, welche auch  'SC 1 - unsynchronisierte Geschwindigkeit überschritten 'als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 1 - unsynchronisierte Geschwindigkeit überschritten ', "message_number"].unique()
# Out:
# array(['20487'], dtype=object)

# %%
X[X.message_number == '20487'][X.message_severity == 'SC 1 - unsynchronisierte Geschwindigkeit überschritten '] # -> 5 mal falsch zugeordne
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739887 2015-09-09 04:36:33          20487           System
# 3877064 2015-10-13 22:53:54          20487           System
# 3877068 2015-10-13 22:53:33          20487           System
# 3877183 2015-10-13 22:34:29          20487           System
# 3877192 2015-10-13 22:32:42          20487           System
#
#                                           message_severity an_title  \
# 3739887  SC 1 - unsynchronisierte Geschwindigkeit übers...      NaN
# 3877064  SC 1 - unsynchronisierte Geschwindigkeit übers...      NaN
# 3877068  SC 1 - unsynchronisierte Geschwindigkeit übers...      NaN
# 3877183  SC 1 - unsynchronisierte Geschwindigkeit übers...      NaN
# 3877192  SC 1 - unsynchronisierte Geschwindigkeit übers...      NaN
#
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 - unsynchronisierte Geschwindigkeit überschritten ': 'Error'})

# Überprüfe message_severity von message_number=20487
df1.loc[df1['message_number'] == '20487', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10400

# %%
# Überprüfe message_severity von message number=10400

X.loc[X['message_number'] == '10400', "message_severity"].unique()
# Out:
# array(['Information', 'Anwender Safety User angemeldet'], dtype=object)

# %%
# Überprüfe ob es außer 10400 andere message_numbers gibt, welche auch  'Anwender Safety User angemeldet' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Anwender Safety User angemeldet', "message_number"].unique()
# Out:
# array(['10400'], dtype=object)

# %%
X[X.message_number == '10400'][X.message_severity == 'Anwender Safety User angemeldet'] # -> 2 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739899 2015-09-09 04:27:48          10400      Operational
# 3877092 2015-10-13 22:50:55          10400      Operational
#
#                         message_severity an_title an_description  an_line  \
# 3739899  Anwender Safety User angemeldet      NaN            NaN  line_23
# 3877092  Anwender Safety User angemeldet      NaN            NaN  line_24
#
#          an_cell   an_robot
# 3739899   cell_3  robot_170
# 3877092  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Anwender Safety User angemeldet': 'Information'})

# Überprüfe message_severity von message_number=10400
df1.loc[df1['message_number'] == '10400', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=20488

# %%
# Überprüfe message_severity von message number=20488

X.loc[X['message_number'] == '20488', "message_severity"].unique()
# Out:
# array(['Warning', 'SC 1 - Zeitlimit für unsynch. Zustand abgelaufen '],
#       dtype=object)

# %%
# Überprüfe ob es außer 20488 andere message_numbers gibt, welche auch  'SC 1 - Zeitlimit für unsynch. Zustand abgelaufen ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Anwender Safety User angemeldet', "message_number"].unique()
# Out:
# array(['10400'], dtype=object)

# %%
X[X.message_number == '20488'][X.message_severity == 'SC 1 - Zeitlimit für unsynch. Zustand abgelaufen '] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3877132 2015-10-13 22:45:42          20488           System
#
#                                           message_severity an_title  \
# 3877132  SC 1 - Zeitlimit für unsynch. Zustand abgelaufen       NaN
#
#         an_description  an_line  an_cell   an_robot
# 3877132            NaN  line_24  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 - Zeitlimit für unsynch. Zustand abgelaufen ': 'Warning'})

# Überprüfe message_severity von message_number=20488
df1.loc[df1['message_number'] == '20488', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20451

# %%
# Überprüfe message_severity von message number=20451

X.loc[X['message_number'] == '20451', "message_severity"].unique()
# Out:
# array(['Error', 'SC 1 nicht synchronisiert '], dtype=object)

# %%
# Überprüfe ob es außer 20451 andere message_numbers gibt, welche auch  'SC 1 nicht synchronisiert ' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'SC 1 nicht synchronisiert ', "message_number"].unique()
# Out:
# array(['20451'], dtype=object)

# %%
X[X.message_number == '20451'][X.message_severity == 'SC 1 nicht synchronisiert '] # -> 3 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739910 2015-09-09 03:34:39          20451           System
# 3877110 2015-10-13 22:47:57          20451           System
# 3877207 2015-10-13 22:29:52          20451           System
#
#                    message_severity an_title an_description  an_line  an_cell  \
# 3739910  SC 1 nicht synchronisiert       NaN            NaN  line_23   cell_3
# 3877110  SC 1 nicht synchronisiert       NaN            NaN  line_24  cell_14
# 3877207  SC 1 nicht synchronisiert       NaN            NaN  line_24  cell_14
#
#           an_robot
# 3739910  robot_170
# 3877110  robot_179
# 3877207  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'SC 1 nicht synchronisiert ': 'Error'})

# Überprüfe message_severity von message_number=20451
df1.loc[df1['message_number'] == '20451', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20454

# %%
# Überprüfe message_severity von message number=20454

X.loc[X['message_number'] == '20454', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20458

# %%
# Überprüfe message_severity von message number=20458

X.loc[X['message_number'] == '20458', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=37054

# %%
# Überprüfe message_severity von message number=37054

X.loc[X['message_number'] == '37054', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20241

# %%
# Überprüfe message_severity von message number=20241

X.loc[X['message_number'] == '20241', "message_severity"].unique()
# Out:
# array(['Error', 'Konflikt Betriebsart'], dtype=object)

# %%
# Überprüfe ob es außer 20241 andere message_numbers gibt, welche auch  'Konflikt Betriebsart' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Konflikt Betriebsart', "message_number"].unique()
# Out:
# array(['20241'], dtype=object)

# %%
X[X.message_number == '20241'][X.message_severity == 'Konflikt Betriebsart'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3873306 2015-10-12 02:14:32          20241           System
#
#              message_severity an_title an_description  an_line  an_cell  \
# 3873306  Konflikt Betriebsart      NaN            NaN  line_24  cell_14
#
#           an_robot
# 3873306  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Konflikt Betriebsart': 'Error'})

# Überprüfe message_severity von message_number=20241
df1.loc[df1['message_number'] == '20241', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=80001

# %%
# Überprüfe message_severity von message number=80001

X.loc[X['message_number'] == '80001', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41630

# %%
# Überprüfe message_severity von message number=41630

X.loc[X['message_number'] == '41630', "message_severity"].unique()
# Out:
# array(['Warning', 'Unsichere Synchronisierung'], dtype=object)

# %%
# Überprüfe ob es außer 41630 andere message_numbers gibt, welche auch  'Unsichere Synchronisierung' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Unsichere Synchronisierung', "message_number"].unique()
# Out:
# array(['41630'], dtype=object)

# %%
X[X.message_number == '41630'][X.message_severity == 'Unsichere Synchronisierung'] # -> 129 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1010906 2015-08-17 22:42:33          41630          Program
# 1010907 2015-08-17 22:42:33          41630          Program
# 1010919 2015-08-17 21:57:00          41630          Program
# 1010920 2015-08-17 21:57:00          41630          Program
# 1010921 2015-08-17 21:22:47          41630          Program
# 1010922 2015-08-17 21:22:47          41630          Program
# 1010923 2015-08-17 21:22:47          41630          Program
# 1010926 2015-08-17 21:20:40          41630          Program
# 1010990 2015-08-17 12:58:16          41630          Program
# 1010991 2015-08-17 12:58:16          41630          Program
# 1011008 2015-08-17 09:16:47          41630          Program
# 1011009 2015-08-17 09:16:47          41630          Program
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Unsichere Synchronisierung': 'Warning'})

# Überprüfe message_severity von message_number=41630
df1.loc[df1['message_number'] == '41630', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=41496

# %%
# Überprüfe message_severity von message number=41496

X.loc[X['message_number'] == '41496', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41499

# %%
# Überprüfe message_severity von message number=41499

X.loc[X['message_number'] == '41499', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20245

# %%
# Überprüfe message_severity von message number=20245

X.loc[X['message_number'] == '20245', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10099

# %%
# Überprüfe message_severity von message number=10099

X.loc[X['message_number'] == '10099', "message_severity"].unique()
# Out:
# array(['Warning', 'Programmstart abgewiesen'], dtype=object)

# %%
# Überprüfe ob es außer 41496 andere message_numbers gibt, welche auch  'Programmstart abgewiesen' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Programmstart abgewiesen', "message_number"].unique()
# Out:
# array(['10099'], dtype=object)

# %%
X[X.message_number == '10099'][X.message_severity == 'Programmstart abgewiesen'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3786534 2015-10-19 06:17:28          10099      Operational
#
#                  message_severity an_title an_description  an_line  an_cell  \
# 3786534  Programmstart abgewiesen      NaN            NaN  line_23  cell_13
#
#           an_robot
# 3786534  robot_167

# %%
df1['message_severity'] = df1.message_severity.replace({'Programmstart abgewiesen': 'Warning'})

# Überprüfe message_severity von message_number=10099
df1.loc[df1['message_number'] == '10099', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=50056

# %%
# Überprüfe message_severity von message number=50056

X.loc[X['message_number'] == '50056', "message_severity"].unique()
# Out:
# array(['Error', 'Achskollision'], dtype=object)

# %%
# Überprüfe ob es außer 50056 andere message_numbers gibt, welche auch  'Achskollision' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Achskollision', "message_number"].unique()
# Out:
# array(['50056'], dtype=object)

# %%
X[X.message_number == '50056'][X.message_severity == 'Achskollision'] # -> 20 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 1118403 2015-08-24 06:53:21          50056           Motion    Achskollision
# 1118409 2015-08-24 06:52:36          50056           Motion    Achskollision
# 1118415 2015-08-24 06:52:25          50056           Motion    Achskollision
# 1118423 2015-08-24 06:51:47          50056           Motion    Achskollision
# 1118429 2015-08-24 06:50:51          50056           Motion    Achskollision
# 1118438 2015-08-24 06:50:16          50056           Motion    Achskollision
# 1118444 2015-08-24 06:49:33          50056           Motion    Achskollision
# 1118453 2015-08-24 06:48:32          50056           Motion    Achskollision
# 1118460 2015-08-24 06:48:21          50056           Motion    Achskollision
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Achskollision': 'Error'})

# Überprüfe message_severity von message_number=50056
df1.loc[df1['message_number'] == '50056', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20315

# %%
# Überprüfe message_severity von message number=20315

X.loc[X['message_number'] == '20315', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=10213

# %%
# Überprüfe message_severity von message number=10213

X.loc[X['message_number'] == '10213', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20213

# %%
# Überprüfe message_severity von message number=20213

X.loc[X['message_number'] == '20213', "message_severity"].unique()
# Out:
# array(['Error', 'Zwei-Kanal-Fehler'], dtype=object)

# %%
# Überprüfe ob es außer 20213 andere message_numbers gibt, welche auch  'Zwei-Kanal-Fehler' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Zwei-Kanal-Fehler', "message_number"].unique()
# Out:
# array(['20213'], dtype=object)

# %%
X[X.message_number == '20213'][X.message_severity == 'Zwei-Kanal-Fehler'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3873307 2015-10-12 02:14:30          20213           System
#
#           message_severity an_title an_description  an_line  an_cell  \
# 3873307  Zwei-Kanal-Fehler      NaN            NaN  line_24  cell_14
#
#           an_robot
# 3873307  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Zwei-Kanal-Fehler': 'Error'})

# Überprüfe message_severity von message_number=20213
df1.loc[df1['message_number'] == '20213', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20204

# %%
# Überprüfe message_severity von message number=20204

X.loc[X['message_number'] == '20204', "message_severity"].unique()
# Out:
# array(['Error', 'Ungleichgewicht Schlüsselschalterkreise'], dtype=object)

# %%
# Überprüfe ob es außer 20204 andere message_numbers gibt, welche auch  'Ungleichgewicht Schlüsselschalterkreise' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Ungleichgewicht Schlüsselschalterkreise', "message_number"].unique()
# Out:
# array(['20204'], dtype=object)

# %%
X[X.message_number == '20204'][X.message_severity == 'Ungleichgewicht Schlüsselschalterkreise'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3873308 2015-10-12 02:14:30          20204           System
#
#                                 message_severity an_title an_description  \
# 3873308  Ungleichgewicht Schlüsselschalterkreise      NaN            NaN
#
#          an_line  an_cell   an_robot
# 3873308  line_24  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Ungleichgewicht Schlüsselschalterkreise': 'Error'})

# Überprüfe message_severity von message_number=20204
df1.loc[df1['message_number'] == '20204', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50065

# %%
# Überprüfe message_severity von message number=50065

X.loc[X['message_number'] == '50065', "message_severity"].unique()
# Out:
# array(['Error', 'Kinematikfehler'], dtype=object)

# %%
# Überprüfe ob es außer 50065 andere message_numbers gibt, welche auch  'Kinematikfehler' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Kinematikfehler', "message_number"].unique()
# Out:
# array(['50065'], dtype=object)

# %%
X[X.message_number == '50065'][X.message_severity == 'Kinematikfehler'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 3877294 2015-10-13 21:14:36          50065           Motion  Kinematikfehler
#
#         an_title an_description  an_line  an_cell   an_robot
# 3877294      NaN            NaN  line_24  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Kinematikfehler': 'Error'})

# Überprüfe message_severity von message_number=50065
df1.loc[df1['message_number'] == '50065', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40634

# %%
# Überprüfe message_severity von message number=40634

X.loc[X['message_number'] == '40634', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10106

# %%
# Überprüfe message_severity von message number=10106

X.loc[X['message_number'] == '10106', "message_severity"].unique()
# Out:
# array(['Error', 'Wartungsmeldung'], dtype=object)

# %%
# Überprüfe ob es außer 10106 andere message_numbers gibt, welche auch  'Wartungsmeldung' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Wartungsmeldung', "message_number"].unique()
# Out:
# array(['10106'], dtype=object)

# %%
X[X.message_number == '10106'][X.message_severity == 'Wartungsmeldung'] # -> 2 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category message_severity  \
# 2967772 2015-08-19 19:11:13          10106      Operational  Wartungsmeldung
# 3236673 2015-08-26 18:38:48          10106      Operational  Wartungsmeldung
#
#         an_title an_description  an_line  an_cell   an_robot
# 2967772      NaN            NaN  line_19  cell_14  robot_143
# 3236673      NaN            NaN  line_19  cell_14  robot_143

# %%
df1['message_severity'] = df1.message_severity.replace({'Wartungsmeldung': 'Error'})

# Überprüfe message_severity von message_number=10106
df1.loc[df1['message_number'] == '10106', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40738

# %%
# Überprüfe message_severity von message number=40738

X.loc[X['message_number'] == '40738', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10067

# %%
# Überprüfe message_severity von message number=10067

X.loc[X['message_number'] == '10067', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20127

# %%
# Überprüfe message_severity von message number=20127

X.loc[X['message_number'] == '20127', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40354

# %%
# Überprüfe message_severity von message number=40354

X.loc[X['message_number'] == '40354', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=41676

# %%
# Überprüfe message_severity von message number=41676

X.loc[X['message_number'] == '41676', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=40151

# %%
# Überprüfe message_severity von message number=40151

X.loc[X['message_number'] == '40151', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10032

# %%
# Überprüfe message_severity von message number=10032

X.loc[X['message_number'] == '10032', "message_severity"].unique()
# Out:
# array(['Information', 'Alle Umdrehungszähler aktualisiert'], dtype=object)

# %%
# Überprüfe ob es außer 10032 andere message_numbers gibt, welche auch  'Alle Umdrehungszähler aktualisiert' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Alle Umdrehungszähler aktualisiert', "message_number"].unique()
# Out:
# array(['10032'], dtype=object)

# %%
X[X.message_number == '10032'][X.message_severity == 'Alle Umdrehungszähler aktualisiert'] # -> 2 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739888 2015-09-09 04:36:33          10032      Operational
# 3877182 2015-10-13 22:34:39          10032      Operational
#
#                            message_severity an_title an_description  an_line  \
# 3739888  Alle Umdrehungszähler aktualisiert      NaN            NaN  line_23
# 3877182  Alle Umdrehungszähler aktualisiert      NaN            NaN  line_24
#
#          an_cell   an_robot
# 3739888   cell_3  robot_170
# 3877182  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Alle Umdrehungszähler aktualisiert': 'Information'})

# Überprüfe message_severity von message_number=10032
df1.loc[df1['message_number'] == '10032', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=20032

# %%
# Überprüfe message_severity von message number=20032

X.loc[X['message_number'] == '20032', "message_severity"].unique()
# Out:
# array(['Error', 'Umdr.-Zähler nicht aktualisiert'], dtype=object)

# %%
# Überprüfe ob es außer 20032 andere message_numbers gibt, welche auch  'Umdr.-Zähler nicht aktualisiert' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Umdr.-Zähler nicht aktualisiert', "message_number"].unique()
# Out:
# array(['20032'], dtype=object)

# %%
X[X.message_number == '20032'][X.message_severity == 'Umdr.-Zähler nicht aktualisiert'] # -> 8 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739894 2015-09-09 04:28:19          20032           System
# 3739902 2015-09-09 04:26:43          20032           System
# 3739926 2015-09-09 03:34:36          20032           System
# 3877186 2015-10-13 22:33:43          20032           System
# 3877190 2015-10-13 22:32:48          20032           System
# 3877195 2015-10-13 22:32:31          20032           System
# 3877200 2015-10-13 22:32:10          20032           System
# 3877211 2015-10-13 22:29:50          20032           System
#
#                         message_severity an_title an_description  an_line  \
# 3739894  Umdr.-Zähler nicht aktualisiert      NaN            NaN  line_23
# 3739902  Umdr.-Zähler nicht aktualisiert      NaN            NaN  line_23
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Umdr.-Zähler nicht aktualisiert': 'Error'})

# Überprüfe message_severity von message_number=20032
df1.loc[df1['message_number'] == '20032', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50091

# %%
# Überprüfe message_severity von message number=50091

X.loc[X['message_number'] == '50091', "message_severity"].unique()
# Out:
# array(['Error', 'Neustart nicht möglich'], dtype=object)

# %%
# Überprüfe ob es außer 50091 andere message_numbers gibt, welche auch  'Neustart nicht möglich' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Neustart nicht möglich', "message_number"].unique()
# Out:
# array(['10091', '50091'], dtype=object)

# %%
X[X.message_number == '50091'][X.message_severity == 'Neustart nicht möglich'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3877209 2015-10-13 22:29:50          50091           Motion
#
#                message_severity an_title an_description  an_line  an_cell  \
# 3877209  Neustart nicht möglich      NaN            NaN  line_24  cell_14
#
#           an_robot
# 3877209  robot_179

# %%
# Überprüfe message_severity von message number=10091

X.loc[X['message_number'] == '10091', "message_severity"].unique()
# Out:
# array(['Warning', 'Neustart nicht möglich'], dtype=object)

# %%
X[X.message_number == '10091'][X.message_severity == 'Neustart nicht möglich'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 1118632 2015-08-24 06:14:05          10091      Operational
#
#                message_severity an_title an_description an_line an_cell  \
# 1118632  Neustart nicht möglich      NaN            NaN  line_4  cell_3
#
#          an_robot
# 1118632  robot_90

# %%
# Korregiere die message_severity-Wert von 50091
df1.loc[df1['message_number'] == '50091', 'message_severity'] = 'Error'

# %%
# Überprüfe die Korrektur
df1[df1.message_number == '50091']
# Out:
#             event_timestamp message_number message_category message_severity  \
# 780360  2016-06-29 10:21:19          50091           Motion            Error
# 1933122 2016-07-05 13:24:42          50091           Motion            Error
# 3877209 2015-10-13 22:29:50          50091           Motion            Error
# 3958751 2016-07-05 12:43:36          50091           Motion            Error
#
#         an_title an_description  an_line  an_cell   an_robot
# 780360       NaN            NaN  line_12  cell_17   robot_85
# 1933122      NaN            NaN  line_15  cell_19  robot_116
# 3877209      NaN            NaN  line_24  cell_14  robot_179
# 3958751      NaN            NaN  line_26  cell_13  robot_183

# %%
# Korregiere die message_severity-Wert von 10091
df1.loc[df1['message_number'] == '10091', 'message_severity'] = 'Warning'

# %%
# Überprüfe die Korrektur
df1[df1.message_number == '10091']
# Out:
#             event_timestamp message_number message_category message_severity  \
# 914481  2015-10-11 14:19:47          10091      Operational          Warning
# 1118632 2015-08-24 06:14:05          10091      Operational          Warning
# 1972188 2016-06-22 22:08:44          10091      Operational          Warning
# 1972246 2016-06-22 22:06:09          10091      Operational          Warning
# 1972257 2016-06-22 22:05:38          10091      Operational          Warning
# 1972263 2016-06-22 22:05:36          10091      Operational          Warning
# 3872398 2016-07-12 10:34:47          10091      Operational          Warning
#
#         an_title an_description  an_line  an_cell   an_robot
# 914481       NaN            NaN   line_4  cell_11   robot_88
# 1118632      NaN            NaN   line_4   cell_3   robot_90
# 1972188      NaN            NaN  line_15   cell_6  robot_121
# 1972246      NaN            NaN  line_15   cell_6  robot_121
# ...

# %% [markdown]
# # message_number=10036

# %%
# Überprüfe message_severity von message number=10036

X.loc[X['message_number'] == '10036', "message_severity"].unique()
# Out:
# array(['Information', 'Umdrehungszähler nicht aktualisiert'], dtype=object)

# %%
# Überprüfe ob es außer 10036 andere message_numbers gibt, welche auch  'Umdrehungszähler nicht aktualisiert' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Umdrehungszähler nicht aktualisiert', "message_number"].unique()
# Out:
# array(['10036'], dtype=object)

# %%
X[X.message_number == '10036'][X.message_severity == 'Umdrehungszähler nicht aktualisiert'] # -> 2 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739924 2015-09-09 03:34:36          10036      Operational
# 3877210 2015-10-13 22:29:50          10036      Operational
#
#                             message_severity an_title an_description  an_line  \
# 3739924  Umdrehungszähler nicht aktualisiert      NaN            NaN  line_23
# 3877210  Umdrehungszähler nicht aktualisiert      NaN            NaN  line_24
#
#          an_cell   an_robot
# 3739924   cell_3  robot_170
# 3877210  cell_14  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Umdrehungszähler nicht aktualisiert': 'Information'})

# Überprüfe message_severity von message_number=10036
df1.loc[df1['message_number'] == '10036', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=50057

# %%
# Überprüfe message_severity von message number=50057

X.loc[X['message_number'] == '50057', "message_severity"].unique()
# Out:
# array(['Error', 'Achse nicht synchron'], dtype=object)

# %%
# Überprüfe ob es außer 50057 andere message_numbers gibt, welche auch  'Achse nicht synchron' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Achse nicht synchron', "message_number"].unique()
# Out:
# array(['50057'], dtype=object)

# %%
X[X.message_number == '50057'][X.message_severity == 'Achse nicht synchron'] # -> 2 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3739927 2015-09-09 03:34:34          50057           Motion
# 3877168 2015-10-13 22:29:47          50057           Motion
#
#              message_severity an_title an_description  an_line  an_cell  \
# 3739927  Achse nicht synchron      NaN            NaN  line_23   cell_3
# 3877168  Achse nicht synchron      NaN            NaN  line_24  cell_14
#
#           an_robot
# 3739927  robot_170
# 3877168  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Achse nicht synchron': 'Error'})

# Überprüfe message_severity von message_number=50057
df1.loc[df1['message_number'] == '50057', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41638

# %%
# Überprüfe message_severity von message number=41638

X.loc[X['message_number'] == '41638', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=38101

# %%
# Überprüfe message_severity von message number=38101

X.loc[X['message_number'] == '38101', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=38209

# %%
# Überprüfe message_severity von message number=38209

X.loc[X['message_number'] == '38209', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20455

# %%
# Überprüfe message_severity von message number=20455

X.loc[X['message_number'] == '20455', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10172

# %%
# Überprüfe message_severity von message number=10172

X.loc[X['message_number'] == '10172', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10014

# %%
# Überprüfe message_severity von message number=10014

X.loc[X['message_number'] == '10014', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=20137

# %%
# Überprüfe message_severity von message number=20137

X.loc[X['message_number'] == '20137', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=41557

# %%
# Überprüfe message_severity von message number=41557

X.loc[X['message_number'] == '41557', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50140

# %%
# Überprüfe message_severity von message number=50140

X.loc[X['message_number'] == '50140', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20148

# %%
# Überprüfe message_severity von message number=20148

X.loc[X['message_number'] == '20148', "message_severity"].unique()
# Out:
# array(['Warning', 'Bestätigung abgelehnt'], dtype=object)

# %%
# Überprüfe ob es außer 20148 andere message_numbers gibt, welche auch  'Bestätigung abgelehnt' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Bestätigung abgelehnt', "message_number"].unique()
# Out:
# array(['20148'], dtype=object)

# %%
X[X.message_number == '20148'][X.message_severity == 'Bestätigung abgelehnt'] # -> 30 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3915385 2015-10-21 06:43:15          20148           System
# 3915386 2015-10-21 06:43:11          20148           System
# 3915387 2015-10-21 06:43:10          20148           System
# 3915388 2015-10-21 06:43:09          20148           System
# 3915389 2015-10-21 06:43:05          20148           System
# 3915390 2015-10-21 06:43:04          20148           System
# 3915391 2015-10-21 06:43:03          20148           System
# 3915392 2015-10-21 06:43:02          20148           System
# 3915393 2015-10-21 06:42:56          20148           System
# 3915394 2015-10-21 06:42:55          20148           System
# 3915395 2015-10-21 06:42:54          20148           System
# 3915396 2015-10-21 06:42:53          20148           System
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'Bestätigung abgelehnt': 'Warning'})

# Überprüfe message_severity von message_number=20148
df1.loc[df1['message_number'] == '20148', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=10171

# %%
# Überprüfe message_severity von message number=10171

X.loc[X['message_number'] == '10171', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40162

# %%
# Überprüfe message_severity von message number=40162

X.loc[X['message_number'] == '40162', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10042

# %%
# Überprüfe message_severity von message number=10042

X.loc[X['message_number'] == '10042', "message_severity"].unique()
# Out:
# array(['Information'], dtype=object)

# %% [markdown]
# # message_number=40322

# %%
# Überprüfe message_severity von message number=40322

X.loc[X['message_number'] == '40322', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=71435

# %%
# Überprüfe message_severity von message number=71435

X.loc[X['message_number'] == '71435', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=71440

# %%
# Überprüfe message_severity von message number=71440

X.loc[X['message_number'] == '71440', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50298

# %%
# Überprüfe message_severity von message number=50298

X.loc[X['message_number'] == '50298', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20193

# %%
# Überprüfe message_severity von message number=20193

X.loc[X['message_number'] == '20193', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=34402

# %%
# Überprüfe message_severity von message number=34402

X.loc[X['message_number'] == '34402', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=34401

# %%
# Überprüfe message_severity von message number=34401

X.loc[X['message_number'] == '34401', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20254

# %%
# Überprüfe message_severity von message number=20254

X.loc[X['message_number'] == '20254', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10098

# %%
# Überprüfe message_severity von message number=10098

X.loc[X['message_number'] == '10098', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=38104

# %%
# Überprüfe message_severity von message number=38104

X.loc[X['message_number'] == '38104', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=38103

# %%
# Überprüfe message_severity von message number=38103

X.loc[X['message_number'] == '38103', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50021

# %%
# Überprüfe message_severity von message number=50021

X.loc[X['message_number'] == '50021', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=50430

# %%
# Überprüfe message_severity von message number=50430

X.loc[X['message_number'] == '50430', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=39520

# %%
# Überprüfe message_severity von message number=39520

X.loc[X['message_number'] == '39520', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20310

# %%
# Überprüfe message_severity von message number=20310

X.loc[X['message_number'] == '20310', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41637

# %%
# Überprüfe message_severity von message number=41637

X.loc[X['message_number'] == '41637', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=10061

# %%
# Überprüfe message_severity von message number=10061

X.loc[X['message_number'] == '10061', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=10062

# %%
# Überprüfe message_severity von message number=10062

X.loc[X['message_number'] == '10062', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=41497

# %%
# Überprüfe message_severity von message number=41497

X.loc[X['message_number'] == '41497', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40708

# %%
# Überprüfe message_severity von message number=40708

X.loc[X['message_number'] == '40708', "message_severity"].unique()
# Out:
# array(['Warning', 'E/A-Einheit nicht aktiviert'], dtype=object)

# %%
# Überprüfe ob es außer 40708 andere message_numbers gibt, welche auch  'E/A-Einheit nicht aktiviert' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'E/A-Einheit nicht aktiviert', "message_number"].unique()
# Out:
# array(['40708'], dtype=object)

# %%
X[X.message_number == '40708'][X.message_severity == 'E/A-Einheit nicht aktiviert'] # -> 10 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3794959 2015-08-21 03:12:09          40708          Program
# 3794972 2015-08-21 03:03:12          40708          Program
# 3795157 2015-08-21 02:28:45          40708          Program
# 3795159 2015-08-21 02:28:28          40708          Program
# 3795161 2015-08-21 02:28:22          40708          Program
# 3795414 2015-08-21 01:57:47          40708          Program
# 3795465 2015-08-21 01:50:29          40708          Program
# 3795487 2015-08-21 01:25:00          40708          Program
# 3795509 2015-08-21 01:21:18          40708          Program
# 3795560 2015-08-21 01:00:50          40708          Program
#
#                     message_severity an_title an_description  an_line  \
# ...

# %%
df1['message_severity'] = df1.message_severity.replace({'E/A-Einheit nicht aktiviert': 'Warning'})

# Überprüfe message_severity von message_number=40708
df1.loc[df1['message_number'] == '40708', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20223

# %%
# Überprüfe message_severity von message number=20223

X.loc[X['message_number'] == '20223', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=71405

# %%
# Überprüfe message_severity von message number=71405

X.loc[X['message_number'] == '71405', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=41472

# %%
# Überprüfe message_severity von message number=41472

X.loc[X['message_number'] == '41472', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41632

# %%
# Überprüfe message_severity von message number=41632

X.loc[X['message_number'] == '41632', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=50288

# %%
# Überprüfe message_severity von message number=50288

X.loc[X['message_number'] == '50288', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40611

# %%
# Überprüfe message_severity von message number=40611

X.loc[X['message_number'] == '40611', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=11223

# %%
# Überprüfe message_severity von message number=11223

X.loc[X['message_number'] == '11223', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=110811

# %%
# Überprüfe message_severity von message number=110811

X.loc[X['message_number'] == '110811', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20484

# %%
# Überprüfe message_severity von message number=20484

X.loc[X['message_number'] == '20484', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40713

# %%
# Überprüfe message_severity von message number=40713

X.loc[X['message_number'] == '40713', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=40355

# %%
# Überprüfe message_severity von message number=40355

X.loc[X['message_number'] == '40355', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=10211

# %%
# Überprüfe message_severity von message number=10211

X.loc[X['message_number'] == '10211', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=50027

# %%
# Überprüfe message_severity von message number=50027

X.loc[X['message_number'] == '50027', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=110812

# %%
# Überprüfe message_severity von message number=110812

X.loc[X['message_number'] == '110812', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20266

# %%
# Überprüfe message_severity von message number=20266

X.loc[X['message_number'] == '20266', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40797

# %%
# Überprüfe message_severity von message number=40797

X.loc[X['message_number'] == '40797', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20450

# %%
# Überprüfe message_severity von message number=20450

X.loc[X['message_number'] == '20450', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=20486

# %%
# Überprüfe message_severity von message number=20486

X.loc[X['message_number'] == '20486', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=40702

# %%
# Überprüfe message_severity von message number=40702

X.loc[X['message_number'] == '40702', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=11022

# %%
# Überprüfe message_severity von message number=11022

X.loc[X['message_number'] == '11022', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=40709

# %%
# Überprüfe message_severity von message number=40709

X.loc[X['message_number'] == '40709', "message_severity"].unique()
# Out:
# array(['E/A-Einheit nicht deaktiviert', 'Warning'], dtype=object)

# %%
# Überprüfe ob es außer 40709 andere message_numbers gibt, welche auch  'E/A-Einheit nicht deaktiviert' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'E/A-Einheit nicht aktiviert', "message_number"].unique()
# Out:
# array(['40708'], dtype=object)

# %%
X[X.message_number == '40709'][X.message_severity == 'E/A-Einheit nicht deaktiviert'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3795062 2015-08-21 02:35:13          40709          Program
#
#                       message_severity an_title an_description  an_line  \
# 3795062  E/A-Einheit nicht deaktiviert      NaN            NaN  line_23
#
#          an_cell   an_robot
# 3795062  cell_11  robot_172

# %%
df1['message_severity'] = df1.message_severity.replace({'E/A-Einheit nicht deaktiviert': 'Warning'})

# Überprüfe message_severity von message_number=40709
df1.loc[df1['message_number'] == '40709', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=50042

# %%
# Überprüfe message_severity von message number=50042

X.loc[X['message_number'] == '50042', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=37230

# %%
# Überprüfe message_severity von message number=37230

X.loc[X['message_number'] == '37230', "message_severity"].unique()
# Out:
# array(['Warnung Bremsenleistung'], dtype=object)

# %%
# Überprüfe ob es außer 37230 andere message_numbers gibt, welche auch  'Warnung Bremsenleistung' als message_severity Kategorie haben

X.loc[X['message_severity'] == 'Warnung Bremsenleistung', "message_number"].unique()
# Out:
# array(['37230'], dtype=object)

# %%
X[X.message_number == '37230'][X.message_severity == 'Warnung Bremsenleistung'] # -> 1 mal falsch zugeordnet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             event_timestamp message_number message_category  \
# 3869042 2015-10-11 18:46:58          37230         Hardware
#
#                 message_severity an_title an_description  an_line  an_cell  \
# 3869042  Warnung Bremsenleistung      NaN            NaN  line_24  cell_14
#
#           an_robot
# 3869042  robot_179

# %%
df1['message_severity'] = df1.message_severity.replace({'Warnung Bremsenleistung': 'Warning'})

# Überprüfe message_severity von message_number=37230
df1.loc[df1['message_number'] == '37230', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=40706

# %%
# Überprüfe message_severity von message number=40706

X.loc[X['message_number'] == '40706', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=40528

# %%
# Überprüfe message_severity von message number=40528

X.loc[X['message_number'] == '40528', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=41687

# %%
# Überprüfe message_severity von message number=41687

X.loc[X['message_number'] == '41687', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20105

# %%
# Überprüfe message_severity von message number=20105

X.loc[X['message_number'] == '20105', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=32530

# %%
# Überprüfe message_severity von message number=32530

X.loc[X['message_number'] == '32530', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41451

# %%
# Überprüfe message_severity von message number=41451

X.loc[X['message_number'] == '41451', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=41617

# %%
# Überprüfe message_severity von message number=41617

X.loc[X['message_number'] == '41617', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # messadge_number=37050

# %%
# Überprüfe message_severity von message number=37050

X.loc[X['message_number'] == '37050', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=37070

# %%
# Überprüfe message_severity von message number=37070

X.loc[X['message_number'] == '37070', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=34307

# %%
# Überprüfe message_severity von message number=34307

X.loc[X['message_number'] == '34307', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=34316

# %%
# Überprüfe message_severity von message number=34316

X.loc[X['message_number'] == '34316', "message_severity"].unique()
# Out:
# array(['Error'], dtype=object)

# %% [markdown]
# # message_number=34303

# %%
# Überprüfe message_severity von message number=34303

X.loc[X['message_number'] == '34303', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %% [markdown]
# # message_number=20453

# %%
# Überprüfe message_severity von message number=20453

X.loc[X['message_number'] == '20453', "message_severity"].unique()
# Out:
# array(['Warning'], dtype=object)

# %%
df1['message_severity'].unique()
# Out:
# array(['Information', 'Warning', 'Error',
#        'Alarm der Profinet-E/A-Einheit',
#        'Automatik-Sicherheitshalt offen', 'Befehl nicht zulässig',
#        'Wiederanfahren fertig', 'Wiederanfahren gestartet',
#        'Backup-Schritt fertig', 'Programm neu gestartet',
#        ' Schweißsteuerung Fehler!! ', ' Schweißzangen Fehler!! ',
#        ' Warte auf Fraeser Umdrehungszaehler ', 'Programm gestartet.',
#        'Programmzeiger wurde zurückgesetzt',
#        ' Warte auf E.-Kappe vorhanden ', ' Warte auf Kühlwasser!! ',
#        ' Warte auf Schweißzangen Kraft Signal ',
#        ' Warte auf Zange MotionCompl Signal ',
#        'Rücksetzen Abarbeitungsfehler', 'Status Abarbeitungsfehler',
#        'Abarbeitungsfehler', 'Kein Kontakt mit Einheit',
#        ' Servozange FS1 Error: 18813 ',
#        ' Warte auf Schweißzangen Motion/Ready Signal ',
#        ' Kopf rueck muss low sein ', ' Warte auf Kappe abgezogen ',
#        ' Eingang Positionierbereit fehlt ',
# ...

# %%
df=df1.copy()

# %%
df.to_parquet("D:/Eclipse Python/DataScience/res/event_ano_new.parquet.gzip", compression='gzip')
